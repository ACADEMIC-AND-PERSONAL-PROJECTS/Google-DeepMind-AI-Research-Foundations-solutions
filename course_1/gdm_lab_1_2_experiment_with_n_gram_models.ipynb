# %% [markdown]
# <a href="https://colab.research.google.com/github/ACADEMIC-AND-PERSONAL-PROJECTS/Google-DeepMind-AI-Research-Foundations-solutions/blob/main/course_1/gdm_lab_1_2_experiment_with_n_gram_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > <p><small><small>This Notebook is made available subject to the licence and terms set out in the <a href = "http://www.github.com/google-deepmind/ai-foundations">AI Research Foundations Github README file</a>.

# %% [markdown]
# <img src="https://storage.googleapis.com/dm-educational/assets/ai_foundations/GDM-Labs-banner-image-C1-white-bg.png">

# %% [markdown]
# # Lab: Experiment with N-Gram Models
#
# <a href='https://colab.research.google.com/github/google-deepmind/ai-foundations/blob/master/course_1/gdm_lab_1_2_experiment_with_n_gram_models.ipynb' target='_parent'><img src='https://colab.research.google.com/assets/colab-badge.svg' alt='Open In Colab'/></a>
#
# Practice extracting n-gram counts and learn how to use them to build a language model.
#
#
# 30 minutes

# %% [markdown]
# ## Overview
#
# In the previous lab, you built a very small language model in which you manually assigned probabilities to the next token for different prompts. In this lab, you will automatically estimate the probabilities for predicting the next word and build an **n-gram model** using a small dataset of paragraphs. This will result in a language model that will be able to predict the next word for a given prompt and that can be used to generate texts. You will also gain a practical understanding of how n-gram models capture language patterns and what the limitations of this family of models are. This knowledge will serve as a foundation for exploring more advanced language models in later modules.

# %% [markdown]
# ### What you will learn:
#
# By the end of this lab, you will be able to:
#
# * Split paragraphs in a dataset into word-like units called tokens, a process known as **tokenization**.
# * Estimate the probabilities for an n-gram language model from a dataset.
# * Use the n-gram language model to predict individual tokens and longer continuations.

# %% [markdown]
# ### Tasks
#
# As mentioned in the previous article, an n-gram is a continuous sequence of $n$ words. An n-gram model uses these sequences to estimate the probability of the next word given a preceding sequence of $n-1$ words (the context).
#
# Recall that you can compute the probability $P(\mbox{B} \mid \mbox{A})$, where $\mbox{B}$ is the next word and $\mbox{A}$ is the context, as follows:
#
# $$P(\mbox{B} \mid \mbox{A}) = \frac{\mbox{Count}(\mbox{A B})}{\mbox{Count}(\mbox{A})}$$
#
# The full n-gram counts, $\mbox{ Count}(\mbox{A B})$, and the context n-gram counts, $\mbox{ Count}(\mbox{A})$, can be computed by counting n-grams in a **dataset**. For building a language model, this dataset is usually a collection of texts, also referred to as a **text corpus**.
#
# **In this lab, you will**:
#
# * Define your dataset, and break the sentences into individual tokens.
# * Create n-grams from the tokens, and calculate counts of n-grams, $\mbox{ Count}(\mbox{A B})$.
# * Estimate $P(\mbox{B} \mid \mbox{A})$ using the n-gram counts.
# * Use the estimated $P(\mbox{B} \mid \mbox{A})$ distributions to generate new text based on your n-gram  language model.

# %% [markdown]
# ## How to use Google Colaboratory (Colab)

# %% [markdown]
# Google Colaboratory (also known as Google Colab) is a platform that allows you to run Python code in your browser. The code is written in *cells* that are executed on a remote server.
#
# To run a cell, hover over a cell and click on the `run` button to its left. The run button is the circle with the triangle (▶). Alternatively, you can also click on a cell and use the keyboard combination Ctrl+Return (or ⌘+Return if you are using a Mac).
#
# To try this out, run the following cell. This should print today's day of the week below it.

# %%
from datetime import datetime
print(f"Today is {datetime.today():%A}.")

# %% [markdown]
# Note that the *order in which you run the cells matters*. When you are working through a lab, make sure to always run *all* cells in order, otherwise the code might not work. If you take a break while working on a lab, Colab may disconnect you and in that case, you have to execute all cells again before  continuing your work. To make this easier, you can select the cell you are currently working on and then choose **Runtime** → **Run before**  from the menu above (or use the keyboard combination Ctrl/⌘ + F8). This will re-execute all cells before the current one.

# %% [markdown]
# ## Imports
#
# The code in this lab uses the [`random`](https://docs.python.org/3/library/random.html) package for sampling from probability distributions, the [`Counter`](https://docs.python.org/3/library/collections.html#collections.Counter) and [`defaultdict`](https://docs.python.org/3/library/collections.html#collections.defaultdict) data types for counting n-grams, and the [`pandas`](https://pandas.pydata.org/) (`pd`) package for constructing data tables.

# %%
# %%capture
# !pip install "git+https://github.com/google-deepmind/ai-foundations.git@main"

# Packages used.
import random # For sampling from probability distributions.
from collections import Counter, defaultdict # For counting n-grams.

import textwrap # For automatically adding linebreaks to long texts.
import pandas as pd # For constructing and visualizing tables.

# Custom functions for providing feedback on your solutions.
from ai_foundations.feedback.course_1 import ngrams

# %% [markdown]
# ## Dataset loading and tokenization
#
# Begin by loading the dataset that you will use to estimate the n-gram counts. For this purpose, you will process the  [Africa Galore](https://storage.googleapis.com/dm-educational/assets/ai_foundations/africa_galore.json) dataset.
#
# The Africa Galore dataset has been designed for this course and consists of synthetically generated paragraphs focusing on diverse aspects of African culture, history, and geography. It has been generated using Google's Gemini language model. Because it is synthetically created, the data is clean, free from the noise and inconsistencies that are often present in real-world datasets. At the same time, given its synthetic nature, the texts may not always be as natural as human-authored texts.
#
# The dataset is specifically designed for educational purposes and the generation process has been guided to ensure that the content is concentrated around the topics relevant to the lab exercises you will be exploring. Its generation process was inspired by the [TinyStories project](https://arxiv.org/abs/2305.07759) [1].
#
# Run the following cell to download the dataset.

# %%
africa_galore = pd.read_json(
    "https://storage.googleapis.com/dm-educational/assets/ai_foundations/africa_galore.json"
)
dataset = africa_galore["description"]
print(f"The dataset consists of {dataset.shape[0]} paragraphs.")

# %% [markdown]
# To get a sense of what these paragraphs look like, inspect the first ten paragraphs in the dataset. You may also want to skim the remainder of the dataset here: [Africa Galore dataset](https://storage.googleapis.com/dm-educational/assets/ai_foundations/africa_galore.json). When working with datasets, it is important to have a good sense of what is in the dataset, since datasets strongly influence the behavior of machine learning models.

# %%
for paragraph in dataset[:10]:
    # textwrap automatically adds line breaks to make long texts more readable.
    formatted_paragraph = textwrap.fill(paragraph)
    print(f"{formatted_paragraph}\n")

# %% [markdown]
# ### Tokenization
#
# Remember that an n-gram is a sequence of $n$ *words*. However, in its current form, the paragraphs are one long string. In order to split the dataset into n-grams and to count them so that you can use them to build a language model, you will have to split these sequences into individual words. This process is referred to as **tokenization**.
#
# The simplest tokenizer is a **space tokenizer**. This tokenizer breaks sentences into individual words based on spaces, that is, the characters that are produced by pressing the space bar. For example, a space tokenizer would tokenize the sentence "Bimpe didn't buy the rice" into the list of words `["Bimpe", "didn't", "buy", "the", "rice"]`.
#
# The cell below implements a space tokenizer in the `space_tokenize` function.

# %%
def space_tokenize(text: str) -> list[str]:
    """Splits a string into a list of words (tokens).

    Splits text on space.

    Args:
        text: The input text.

    Returns:
        A list of tokens. Returns empty list if text is empty or all spaces.
    """
    tokens = text.split(" ")
    return tokens

# Tokenize an example text with the `space_tokenize` function.
space_tokenize("Kanga, a colorful printed cloth is more than just a fabric.")

# %% [markdown]
# Note that the space tokenizer is quite naive. When you are tokenizing based only on spaces, you will observe that the punctuation marks are often considered part of the words. For example, tokenizing the sentence "Table mountain is tall."  will result in a different list of words than tokenizing "Table mountain is tall". The first sentence results in (`["Table", "mountain", "is", "tall."]`. The second sentence, which has the period missing from the end, will result in `["Table", "mountain", "is", "tall"]`). Since the units that tokenizers split sequences into are not always a word, they are usually referred to as **tokens**. In many cases, a token will be the same as a word but it may also be non-word strings, such as "tall." or "3/4".
#
# You will learn about more sophisticated methods for tokenizing texts in later courses. For the purpose of this lab, the space tokenizer will be sufficient and you will use the implementation of the `space_tokenize` function that you observed in the previous cell.

# %% [markdown]
# To get an impression of what the tokenized data looks like, run the cell below to tokenize the first paragraph in the dataset.

# %%
space_tokenize(dataset[0])

# %% [markdown]
# ## Coding Activity 1: From lists of tokens to n-grams
#
# The `space_tokenize` function returns a list of individual tokens. However, to compute the conditional probability of a token $\mbox{B}$ following a context $\mbox{A}$, $P(\mbox{B} \mid \mbox{A})$, you need to determine how often all n-grams and (n-1)-grams appear in your dataset.
#
# For example, if you want to compute the probability of the token "is" following a bigram (2-gram) "Table Mountain", then you need to know the counts of the trigram (3-gram) "Table Mountain is" and the bigram "Table Mountain". More generally, to build an n-gram language model, you need to determine the counts of all n-grams and (n-1)-grams. As a first step towards obtaining these counts, you will write a function that turns a list of tokens into a list of n-grams.

# %% [markdown]
# ------
# > 💻 **Your task**:
# >
# > Complete the function `generate_ngrams(text: str, n: int)` below.
# >
# > This function should return a list of n-grams of length $n$ for a text. Each n-gram should be represented as a tuple of tokens. The function should therefore return a list of tuples of strings. You can use the [`tuple()`](https://www.w3schools.com/python/python_tuples.asp) function to convert a list of strings to a tuple of strings.
# >
# > Your function will first have to tokenize the text. You can use the `space_tokenize` function from above for this purpose. Second, the function needs to construct the list of n-grams for the text.
# >
# > For example, if the input to the function is `text = "Table Mountain is tall."` and `n = 2`, the function should return the following list of bigrams:
# > ```
# > [
# >  ("Table", "Mountain"),
# >  ("Mountain", "is"),
# >  ("is", "tall.")
# > ]
# > ```
# >
# > Once you have finished your implementation, run the cell below to print the first ten unigrams, bigrams, and trigrams that appear in the dataset.
# ------

# %%
all_unigrams = []
all_bigrams = []
all_trigrams = []

def generate_ngrams(text: str, n: int) -> list[tuple[str]]:
    """Generates n-grams from a given text.

    Args:
        text: The input text string.
        n: The size of the n-grams (e.g., 2 for bigrams, 3 for trigrams).

    Returns:
        A list of n-grams, each represented as a list of tokens.
    """

    # Tokenize text.
    tokens = ...  # Add your code here.

    # Construct the list of n-grams.
    ngrams = []

    # Add your code here.

    return ngrams

for paragraph in dataset:
    # Calling `generate_ngrams` with n=1 constructs a list of unigrams.
    all_unigrams.extend(generate_ngrams(paragraph, n=1))
    # Calling `generate_ngrams` with n=2 constructs a list of bigrams (2-grams).
    all_bigrams.extend(generate_ngrams(paragraph, n=2))
    # Calling `generate_ngrams` with n=2 constructs a list of trigram (3-grams).
    all_trigrams.extend(generate_ngrams(paragraph, n=3))

print("First 10 Unigrams:", all_unigrams[:10])
print("First 10 Bigrams:", all_bigrams[:10])
print("First 10 Trigrams:", all_trigrams[:10])

# %%
# @title Run this cell to test your implementation.
ngrams.test_generate_ngrams(generate_ngrams, space_tokenize)

# %% [markdown]
# The main reason for counting n-grams and using these counts to compute probabilities is that these probabilities can capture **patterns** in language. In this context, frequent n-grams are usually more interesting than very rare n-grams since they capture frequent co-occurrences of words (e.g., "Table Mountain" or "jollof rice").
#
# Run the following cell to compute which n-grams appear most frequently in the dataset.
# The output of the cell below is a list of tuples of the format `(ngram, number of occurrences)`. For example, the output shows you that the bigram `("is",  "a")` appears 144 times in the Africa Galore dataset.

# %%
# Use the Python Counter data type for computing the counts of all bigrams.
# See: https://docs.python.org/3/library/collections.html#collections.Counter
bigram_counts = Counter(all_bigrams)

# Print the ten most common bigrams.
print("Most common bigrams:")
for bigram, count in bigram_counts.most_common(10):
    print(f"  ({bigram}, {count})")

# Use the Python Counter data type for computing the counts of all trigrams.
trigram_counts = Counter(all_trigrams)

# Print the ten most common trigrams.
print("\n\nMost common trigrams:")
for trigram, count in trigram_counts.most_common(10):
    print(f"  ({trigram}, {count})")

# %% [markdown]
# ## Coding Activity 2: Counting n-grams
#
# In preparation for computing the probabilities, you require a function that returns the counts of n-grams.

# %% [markdown]
# ------
# > 💻 **Your task**:
# >
# > Complete the function `get_ngram_counts(dataset, n)` below.
# >
# > This function should return a dictionary of [`Counter`](https://docs.python.org/3/library/collections.html#collections.Counter) objects where the keys are contexts of length n-1 tokens and the values are counters for the last token in the n-gram.
# >
# >For example, if the dataset consists of the two sentences "Table Mountain is tall." and "Table Mountain is beautiful." then the function called with `n = 3` should return:
# >```
# >{
# >   "Table Mountain": Counter({"is": 2}),
# >   "Mountain is": Counter({"tall": 1, "beautiful": 1})
# >}
# >```
# ------

# %%
def get_ngram_counts(dataset: list[str], n: int) -> dict[str, Counter]:
    """Computes the n-gram counts from a dataset.

    This function takes a list of text strings (paragraphs or sentences) as
    input, constructs n-grams from each text, and creates a dictionary where:

    * Keys represent n-1 token long contexts `context`.
    * Values are a Counter object `counts` such that `counts[next_token]` is the
      count of `next_token` following `context`.

    Args:
        dataset: The list of text strings in the dataset.
        n: The size of the n-grams to generate (e.g., 2 for bigrams, 3 for
            trigrams).

    Returns:
        A dictionary where keys are (n-1)-token contexts and values are Counter
        objects storing the counts of each next token for that context.

    """

    # Define the dictionary as a defaultdict that is automatically initialized
    # with an empty Counter object. This allows you to access and set the value
    # of ngram_counts[context][next_token] without initializing
    # ngram_counts[context] or ngram_counts[context][next_token] first.
    # Reference
    # https://docs.python.org/3/library/collections.html#collections.Counter and
    # https://docs.python.org/3/library/collections.html#collections.defaultdict
    # for more information on how to use defaultdict and Counter types.
    ngram_counts = defaultdict(Counter)

    for paragraph in dataset:
        # Add your code here.
        ...

    return dict(ngram_counts)


# Example usage of the function.
example_data = [
    "This is an example sentence.",
    "Another example sentence.",
    "Split a sentence."
]
ngram_counts = get_ngram_counts(example_data, 2)

# Print the bigram counts dictionary for the dataset consisting of the
# three example sentences.
print("Bigram counts dictionary:\n")
print("{")
for context, counter in ngram_counts.items():
    print(f"  '{context}': {counter},")
print("}")

# %% [markdown]
# As you can see in the output, the count of the bigram "example sentence." is 2, which is shown in the entry for `"example"`.

# %%
# @title Run this cell to test your implementation.
ngrams.test_ngram_counts(get_ngram_counts, generate_ngrams)

# %% [markdown]
# ### Exploring the n-gram counts in the Africa Galore dataset
#
# You can now use the `get_ngram_counts` function to compute the bigram counts for all combinations of tokens in the Africa Galore dataset.
#
# Run the following cell to print a table of bigram counts. This table shows the count of all bigrams where the first token in the bigram is shown at the beginning of each row and the second token is shown at top of each column.

# %%
bigram_counts = get_ngram_counts(dataset, n=2)

# Use the pandas library to display the counts in a table.
bigram_counts_matrix = {
    context: dict(counts) for context, counts in bigram_counts.items()
}
bigram_data_frame = pd.DataFrame.from_dict(
    bigram_counts_matrix, orient="index").fillna(0)

display(bigram_data_frame)

zero_count = (bigram_data_frame == 0).sum().sum()
print(
    f"Number of bigrams with a count of 0: {zero_count:,}"
    f" ({zero_count/bigram_data_frame.size * 100:.2f}%)"
)

# %% [markdown]
# As you can observe from the table, a lot of entries are 0. This is because the table shows (almost) every possible combination of all tokens that appear in the Africa Galore dataset. In total, there are $5,143 \times 5,176$ possible combinations but most of them (99.95%) never appear in the dataset. This **sparsity** is an important property to consider when building n-gram language models. For any context $\mbox{A}$, the probability $P(\mbox{B} \mid \mbox{A})$ will be 0 for most tokens $\mbox{B}$.

# %% [markdown]
# The sparsity increases even more as the length of the context increases. For an example of this, run the following cell, which computes the frequencies of all trigrams and displays them as a table:

# %%
trigram_counts = get_ngram_counts(dataset, n=3)

# Use the pandas library to display the counts in a table.
trigram_counts_matrix = {
    context: dict(counts) for context, counts in trigram_counts.items()
}
trigram_data_frame = pd.DataFrame.from_dict(
    trigram_counts_matrix, orient="index").fillna(0)

display(trigram_data_frame)

zero_count = (trigram_data_frame == 0).sum().sum()
print(
    f"Number of trigrams with a count of 0: {zero_count:,}"
    f" ({zero_count/trigram_data_frame.size * 100:.2f}%)"
)

# %% [markdown]
# The table above contains even more entries since it contains one entry for each combination of bigram (the columns) and token (the rows) that appears in the dataset. In the case of Africa Galore, this results in $13,411\times 5,142$ combinations. In this example, an even higher percentage of entries (99.98%) in the table are 0. Keep the concept of sparsity in mind as you use these counts to compute probabilities and use the probabilities to generate texts.

# %% [markdown]
# ## Calculate P(B | A)
#
# In the previous activities, you have laid all the groundwork for performing the last computation: computing the probability of a token $\mbox{B}$ following a context $\mbox{A}$.
#
# $$P(\mbox{B} \mid \mbox{A}) = \frac{\mbox{Count}(\mbox{A B})}{\mbox{Count}(\mbox{A})}$$
#
# Using the `get_ngram_counts` function above, you can compute both $\mbox{Count}(\mbox{A B})$ and $\mbox{Count}(\mbox{A})$. For example, if you wanted to estimate probabilities of a trigram model that uses a context of length 2, you could compute the counts in the numerator and the denominator for a `dataset` as:
#
# ```python
# # Counts for the numerator.
# trigram_counts = get_ngram_counts(dataset, n=3)
# # Counts for the denominator.
# bigram_counts = get_ngram_counts(dataset, n=2)
# ```
#
# However, there is a small trick that computes the bigram counts directly from the trigram counts without calling `get_ngram_counts` a second time.
#
# To observe how this works, consider the trigram counts for all trigrams that start with the bigram "a staple." You can access these using the dictionary `trigram_counts` that is defined above:

# %%
context = "a staple"
trigram_counts[context]

# %% [markdown]
# The counter in the output of the previous cell shows you that the dataset contains the following trigrams starting with "a staple":
#
# * "a staple food" (1 time).
# * "a staple in" (6 times).
# * "a staple dish" (2 times).
# * "a staple throughout" (1 time).
# * "a staple of" (1 time).
# * "a staple at" (1 time).
# * "a staple beverage" (1 time).
#
# The trick to get the bigram count of "a staple" is to sum the number of trigrams that start with "a staple." From the counter above, we can compute this total by summing $1+6+2+1+1+1+1 = 13$.
#
# The following cell shows you how to do this automatically using the `sum()` function and the `values()` method of a counter.

# %%
context = "a staple"
# Compute the bigram count for "a staple" with sum().
bigram_count_a_staple = sum(trigram_counts[context].values())

print(
    'Bigram count of "a staple" computed indirectly from trigram counts: ',
    bigram_count_a_staple,
)

# Extract the bigram count for "a staple" from bigram_counts.
print('Bigram count of "a staple" computed directly: ',
      bigram_counts["a"]["staple"])

# %% [markdown]
# As the output of the cell above shows, both using the `sum()` function and computing the bigram counts indirectly results in the same number.

# %% [markdown]
# ### Coding Activity 3: Computing the n-gram probabilities
#
# ------
# > 💻 **Your task**:
# >
# > Complete the function `build_ngram_model(dataset, n)` below.
# >
# > This function should return a dictionary of dictionaries where the keys are contexts of length $n-1$ tokens and the values are a dictionary providing the probabilities of the next token given the context.
# >
# >For example, if the dataset consists of the two sentences "Table Mountain is tall." and "Table Mountain is beautiful." then the function called with `n = 3` should return:
# >```
# >{
# >   "Table Mountain": {"is": 1.0},
# >   "Mountain is": {"tall": 0.5, "beautiful": 0.5}
# >}
# >```
# ------

# %%
def build_ngram_model(
    dataset: list[str],
    n: int
) -> dict[str, dict[str, float]]:
    """Builds an n-gram language model.

    This function takes a list of text strings (paragraphs or sentences) as
    input, generates n-grams from each text using the function get_ngram_counts
    and converts them into probabilities.  The resulting model is a dictionary,
    where keys are (n-1)-token contexts and values are dictionaries mapping
    possible next tokens to their conditional probabilities given the context.

    Args:
        dataset: A list of text strings representing the dataset.
        n: The size of the n-grams (e.g., 2 for a bigram model).

    Returns:
        A dictionary representing the n-gram language model, where keys are
        (n-1)-tokens contexts and values are dictionaries mapping possible next
        tokens to their conditional probabilities.
    """

    # A dictionary to store P(B | A).
    # ngram_model[context][token] should store P(token | context).
    ngram_model = {}

    # Use the ngram_counts as computed by the get_ngram_counts function.
    ngram_counts = get_ngram_counts(dataset, n)

    # Loop through the possible contexts. `context` is a string
    # and `next_tokens` is a dictionary mapping possible next tokens to their
    # counts of following `context`.
    for context, next_tokens in ngram_counts.items():

        # Compute Count(A) and P(B | A) here.
        # Add your code here.
        count_context = sum(next_tokens.values())
        ngram_model[context] =  {}
        for next_token, count in next_tokens.items():
          ngram_model[context][next_token] = count / count_context

    return ngram_model

# Test the method above by bulding a simple trigram model.
test_dataset = ["Table Mountain is tall.", "Table Mountain is beautiful."]
test_trigram_model = build_ngram_model(test_dataset, n=3)
test_trigram_model
# Out:
# {'Table Mountain': {'is': 1.0},
#  'Mountain is': {'tall.': 0.5, 'beautiful.': 0.5}}

# %%
# @title Run this cell to test your implementation.
ngrams.test_build_ngram_model(build_ngram_model, get_ngram_counts)
# Out:
# ✅ Nice! Your implementation looks correct.

# %% [markdown]
# After you have successfully implemented the method above, run the following cell to construct a trigram model that estimates the probabilities from the Africa Galore dataset.

# %%
trigram_model = build_ngram_model(dataset, n=3)

# %%
trigram_model
# Out:
# {'The Lagos': {'air': 1.0},
#  'Lagos air': {'was': 1.0},
#  'air was': {'thick': 0.2222222222222222,
#   'thin': 0.1111111111111111,
#   'always': 0.1111111111111111,
#   'quiet,': 0.1111111111111111,
#   'filled': 0.3333333333333333,
#   'alive': 0.1111111111111111},
#  'was thick': {'with': 1.0},
#  'thick with': {'humidity,': 0.3333333333333333, 'the': 0.6666666666666666},
#  'with humidity,': {'but': 1.0},
#  'humidity, but': {'the': 1.0},
#  'but the': {'energy': 1.0},
#  'the energy': {'in': 0.3333333333333333,
#   'of': 0.3333333333333333,
#   'needed': 0.3333333333333333},
#  'energy in': {'the': 1.0},
#  'in the': {'club': 0.01639344262295082,
#   'infectious': 0.01639344262295082,
#   'music.': 0.03278688524590164,
#   'bustling': 0.01639344262295082,
#   'heart': 0.03278688524590164,
#   'face': 0.01639344262295082,
#   '19th': 0.01639344262295082,
#   'surrounding': 0.01639344262295082,
#   'winter': 0.01639344262295082,
#   'west': 0.01639344262295082,
#   'east.': 0.01639344262295082,
#   'fiery': 0.01639344262295082,
#   'Jollof': 0.01639344262295082,
#   'Ethiopian': 0.03278688524590164,
#   'base': 0.01639344262295082,
#   'back': 0.01639344262295082,
#   'afternoon': 0.03278688524590164,
#   'center': 0.01639344262295082,
#   'rich': 0.01639344262295082,
#   'evening': 0.01639344262295082,
#   'world': 0.01639344262295082,
#   'world,': 0.04918032786885246,
#   'maze': 0.01639344262295082,
#   'corrugated': 0.01639344262295082,
#   'air': 0.01639344262295082,
#   'small': 0.01639344262295082,
#   'turquoise': 0.01639344262295082,
#   'shallows,': 0.01639344262295082,
#   'village': 0.01639344262295082,
#   'mountains': 0.01639344262295082,
#   'shade': 0.01639344262295082,
#   'desert': 0.01639344262295082,
#   'fields,': 0.03278688524590164,
#   'world.': 0.06557377049180328,
#   'garden,': 0.01639344262295082,
#   'sun.': 0.01639344262295082,
#   'Congo': 0.01639344262295082,
#   'same': 0.01639344262295082,
#   'city': 0.01639344262295082,
#   'pot': 0.01639344262295082,
#   'batter,': 0.01639344262295082,
#   'African': 0.03278688524590164,
#   'busy': 0.01639344262295082,
#   'heat,': 0.01639344262295082,
#   'East': 0.01639344262295082,
#   'south': 0.01639344262295082,
#   'food': 0.01639344262295082,
#   'high-altitude': 0.01639344262295082,
#   'sea,': 0.01639344262295082,
#   'Southern': 0.01639344262295082},
#  'the club': {'was': 1.0},
#  'club was': {'electric.': 1.0},
#  'was electric.': {'The': 1.0},
#  'electric. The': {'band': 1.0},
#  'The band': {'launched': 1.0},
#  'band launched': {'into': 1.0},
#  'launched into': {'a': 1.0},
#  'into a': {'hypnotic': 0.07692307692307693,
#   'unique': 0.07692307692307693,
#   'small': 0.07692307692307693,
#   'smooth,': 0.07692307692307693,
#   'narrow': 0.07692307692307693,
#   'smooth': 0.07692307692307693,
#   'stiff': 0.07692307692307693,
#   'dough,': 0.07692307692307693,
#   'thick,': 0.15384615384615385,
#   'mildly': 0.07692307692307693,
#   'spirit': 0.07692307692307693,
#   'lush': 0.07692307692307693},
#  'a hypnotic': {'Afrobeat': 1.0},
#  'hypnotic Afrobeat': {'groove,': 1.0},
#  'Afrobeat groove,': {'the': 1.0},
#  'groove, the': {'drums': 1.0},
#  'the drums': {'pounding': 0.5, 'driving': 0.5},
#  'drums pounding': {'out': 1.0},
#  'pounding out': {'a': 1.0},
#  'out a': {'complex': 0.5, 'life': 0.5},
#  'a complex': {'polyrhythm,': 0.25,
#   'process': 0.25,
#   'system': 0.25,
#   'internal': 0.25},
#  'complex polyrhythm,': {'the': 1.0},
#  'polyrhythm, the': {'horns': 1.0},
#  'the horns': {'blaring': 0.5, 'adding': 0.5},
#  'horns blaring': {'a': 1.0},
#  'blaring a': {'soaring': 1.0},
#  'a soaring': {'melody,': 1.0},
#  'soaring melody,': {'and': 1.0},
#  'melody, and': {'the': 1.0},
#  'and the': {'bass': 0.014492753623188406,
#   'hypnotic': 0.014492753623188406,
#   "singers'": 0.014492753623188406,
#   'dynamic': 0.014492753623188406,
#   'savannas': 0.014492753623188406,
#   'vibrant': 0.028985507246376812,
#   'rich': 0.028985507246376812,
#   'views': 0.014492753623188406,
#   'generations': 0.014492753623188406,
#   'earthy': 0.014492753623188406,
#   'magic': 0.014492753623188406,
#   'dried': 0.014492753623188406,
#   'smoky': 0.014492753623188406,
#   'simple': 0.014492753623188406,
#   'history': 0.014492753623188406,
#   'love': 0.014492753623188406,
#   'warmth': 0.014492753623188406,
#   'cries': 0.014492753623188406,
#   'tantalizing': 0.014492753623188406,
#   'burst': 0.014492753623188406,
#   'clinking': 0.014492753623188406,
#   'rhythmic': 0.028985507246376812,
#   'anticipation': 0.014492753623188406,
#   'power': 0.014492753623188406,
#   'surrounding': 0.014492753623188406,
#   'smiling': 0.014492753623188406,
#   'chatter': 0.014492753623188406,
#   'future': 0.014492753623188406,
#   'dedication': 0.014492753623188406,
#   'occasional': 0.028985507246376812,
#   'friendly': 0.014492753623188406,
#   'air': 0.043478260869565216,
#   'enduring': 0.014492753623188406,
#   'rhythm': 0.014492753623188406,
#   'abundance': 0.014492753623188406,
#   'harsh': 0.014492753623188406,
#   'sense': 0.014492753623188406,
#   'landscape': 0.014492753623188406,
#   'gentle': 0.014492753623188406,
#   'beauty': 0.014492753623188406,
#   'distant': 0.014492753623188406,
#   'fertile': 0.014492753623188406,
#   'rhythms': 0.014492753623188406,
#   'Sahara': 0.014492753623188406,
#   'Pacific,': 0.014492753623188406,
#   'cultural': 0.014492753623188406,
#   'specific': 0.014492753623188406,
#   'dish': 0.014492753623188406,
#   'scooped-out': 0.014492753623188406,
#   'leaves': 0.014492753623188406,
#   'general': 0.014492753623188406,
#   'Kgalagadi': 0.014492753623188406,
#   'Blue': 0.014492753623188406,
#   'endangered': 0.014492753623188406,
#   'highest': 0.014492753623188406,
#   'largest': 0.014492753623188406,
#   'camel': 0.014492753623188406,
#   "Grévy's": 0.014492753623188406,
#   'Black': 0.014492753623188406,
#   'distinctive': 0.014492753623188406,
#   'rarest': 0.014492753623188406,
#   'lesser': 0.014492753623188406,
#   'dramatic': 0.014492753623188406},
#  'the bass': {'laying': 1.0},
#  'bass laying': {'down': 1.0},
#  'laying down': {'a': 1.0},
#  'down a': {'deep,': 1.0},
#  'a deep,': {'funky': 1.0},
#  'deep, funky': {'foundation.': 1.0},
#  'funky foundation.': {'A': 1.0},
#  'foundation. A': {'woman': 1.0},
#  'A woman': {'named': 1.0},
#  'woman named': {'Imani': 0.5, 'Akosua': 0.5},
#  'named Imani': {'moved': 1.0},
#  'Imani moved': {'effortlessly': 1.0},
#  'moved effortlessly': {'to': 1.0},
#  'effortlessly to': {'the': 1.0},
#  'to the': {'music,': 0.047619047619047616,
#   'beat': 0.023809523809523808,
#   'beat,': 0.023809523809523808,
#   'deep': 0.023809523809523808,
#   'enduring': 0.023809523809523808,
#   'ingenuity': 0.023809523809523808,
#   'more': 0.023809523809523808,
#   'power': 0.09523809523809523,
#   'dense': 0.023809523809523808,
#   'south,': 0.023809523809523808,
#   "region's": 0.023809523809523808,
#   'dry': 0.023809523809523808,
#   'land': 0.047619047619047616,
#   'chicken,': 0.023809523809523808,
#   'afterlife': 0.023809523809523808,
#   'Cape': 0.023809523809523808,
#   'experience.': 0.023809523809523808,
#   'resilience': 0.023809523809523808,
#   'rugged': 0.023809523809523808,
#   'human': 0.023809523809523808,
#   'vowels': 0.023809523809523808,
#   'religious': 0.023809523809523808,
#   "Asante's": 0.023809523809523808,
#   'mythical': 0.023809523809523808,
#   'brim': 0.023809523809523808,
#   'fermenting': 0.023809523809523808,
#   'region': 0.023809523809523808,
#   'Mediterranean': 0.023809523809523808,
#   'remote': 0.023809523809523808,
#   "pan's": 0.023809523809523808,
#   'open': 0.023809523809523808,
#   'rainforests': 0.023809523809523808,
#   '17th': 0.023809523809523808,
#   'individual.': 0.023809523809523808,
#   "'dancing'": 0.023809523809523808,
#   'eastern': 0.023809523809523808,
#   'savannas': 0.023809523809523808},
#  'the music,': {'her': 0.5, 'their': 0.5},
#  'music, her': {'body': 1.0},
#  'her body': {'swaying': 1.0},
#  'body swaying': {'in': 1.0},
#  'swaying in': {'time': 1.0},
#  'in time': {'with': 1.0},
#  'time with': {'the': 0.5, 'her': 0.5},
#  'with the': {'rhythm.': 0.03225806451612903,
#   'lilting': 0.03225806451612903,
#   'sounds': 0.0967741935483871,
#   'infectious': 0.03225806451612903,
#   'rhythmic': 0.03225806451612903,
#   'other': 0.03225806451612903,
#   'rich': 0.03225806451612903,
#   'smoky': 0.03225806451612903,
#   'thud': 0.03225806451612903,
#   'pungent': 0.03225806451612903,
#   'savory': 0.03225806451612903,
#   'energy': 0.03225806451612903,
#   'scent': 0.0967741935483871,
#   'traders.': 0.03225806451612903,
#   'rhythms': 0.03225806451612903,
#   'rustling': 0.03225806451612903,
#   'salty': 0.03225806451612903,
#   'elements,': 0.03225806451612903,
#   'water': 0.03225806451612903,
#   'sights,': 0.03225806451612903,
#   'chirping': 0.03225806451612903,
#   'tongue': 0.03225806451612903,
#   'essential': 0.03225806451612903,
#   'hands,': 0.03225806451612903,
#   'help': 0.03225806451612903,
#   'Mediterranean.': 0.03225806451612903,
#   'greater': 0.03225806451612903},
#  'the rhythm.': {'The': 1.0},
#  'rhythm. The': {'music': 1.0},
#  'The music': {'seemed': 0.25, 'was': 0.75},
#  'music seemed': {'to': 1.0},
#  'seemed to': {'flow': 1.0},
#  'to flow': {'through': 1.0},
#  'flow through': {'her,': 1.0},
#  'through her,': {'a': 1.0},
#  'her, a': {'powerful': 1.0},
#  'a powerful': {'current': 0.25, 'and': 0.25, 'symbol': 0.5},
#  'powerful current': {'of': 1.0},
#  'current of': {'energy': 1.0},
#  'of energy': {'and': 1.0},
#  'energy and': {'joy.': 0.2, 'inspiration,': 0.2, 'a': 0.4, 'dynamism.': 0.2},
#  'and joy.': {'All': 1.0},
#  'joy. All': {'around': 1.0},
#  'All around': {'her,': 1.0},
#  'around her,': {'people': 1.0},
#  'her, people': {'were': 1.0},
#  'people were': {'dancing,': 1.0},
#  'were dancing,': {'singing,': 1.0},
#  'dancing, singing,': {'and': 1.0},
#  'singing, and': {'clapping,': 1.0},
#  'and clapping,': {'caught': 1.0},
#  'clapping, caught': {'up': 1.0},
#  'caught up': {'in': 1.0},
#  'up in': {'the': 1.0},
#  'the infectious': {'rhythm.': 0.5, 'energy': 0.5},
#  'infectious rhythm.': {'The': 1.0},
#  'music was': {'more': 0.3333333333333333, 'a': 0.6666666666666666},
#  'was more': {'than': 1.0},
#  'more than': {'just': 0.8,
#   'the': 0.06666666666666667,
#   '100': 0.06666666666666667,
#   'anything.': 0.06666666666666667},
#  'than just': {'entertainment;': 0.07692307692307693,
#   'music;': 0.07692307692307693,
#   'a': 0.38461538461538464,
#   'food;': 0.38461538461538464,
#   'food.': 0.07692307692307693},
#  'just entertainment;': {'it': 1.0},
#  'entertainment; it': {'was': 1.0},
#  'it was': {'a': 0.7857142857142857,
#   'ready,': 0.07142857142857142,
#   'smooth': 0.07142857142857142,
#   'missing.': 0.07142857142857142},
#  'was a': {'celebration': 0.02564102564102564,
#   'soundtrack': 0.02564102564102564,
#   'constant': 0.05128205128205128,
#   'way': 0.02564102564102564,
#   'burst': 0.05128205128205128,
#   'symbol': 0.1794871794871795,
#   'symphony': 0.07692307692307693,
#   'special': 0.02564102564102564,
#   'taste': 0.05128205128205128,
#   'perfect': 0.02564102564102564,
#   'comforting': 0.02564102564102564,
#   'feast': 0.02564102564102564,
#   'quick,': 0.02564102564102564,
#   'reminder': 0.02564102564102564,
#   'nutritious': 0.02564102564102564,
#   'beacon': 0.02564102564102564,
#   'place': 0.05128205128205128,
#   'testament': 0.05128205128205128,
#   'haven': 0.05128205128205128,
#   'social': 0.02564102564102564,
#   'microcosm': 0.05128205128205128,
#   'sanctuary': 0.02564102564102564,
#   'simple': 0.02564102564102564,
#   'world-renowned': 0.02564102564102564},
#  'a celebration': {'of': 1.0},
#  'celebration of': {'life,': 0.25,
#   'life': 0.25,
#   'Yoruba': 0.25,
#   'Kenyan': 0.25},
#  'of life,': {'a': 1.0},
#  'life, a': {'connection': 0.2,
#   'reminder': 0.2,
#   'source': 0.2,
#   'vibrant': 0.4},
#  'a connection': {'to': 1.0},
#  'connection to': {'their': 0.5, 'the': 0.5},
#  'to their': {'shared': 0.25, 'favorite': 0.25, 'calorie': 0.25, 'high': 0.25},
#  'their shared': {'heritage,': 0.3333333333333333,
#   'Ethiopian': 0.3333333333333333,
#   'passion': 0.3333333333333333},
#  'shared heritage,': {'a': 1.0},
#  'heritage, a': {'vibrant': 0.25,
#   'connection': 0.25,
#   'taste': 0.25,
#   'testament': 0.25},
#  'a vibrant': {'expression': 0.23076923076923078,
#   'symbol': 0.07692307692307693,
#   'and': 0.15384615384615385,
#   'headscarf,': 0.07692307692307693,
#   'red': 0.07692307692307693,
#   'blend': 0.07692307692307693,
#   'labyrinth': 0.07692307692307693,
#   'hub': 0.07692307692307693,
#   'red-orange': 0.07692307692307693,
#   'market': 0.07692307692307693},
#  'vibrant expression': {'of': 1.0},
#  'expression of': {'the': 0.25,
#   'Senegalese': 0.25,
#   'Ghanaian': 0.25,
#   'Yoruba': 0.25},
#  'of the': {'soul': 0.01,
#   'rich': 0.01,
#   'maker.': 0.01,
#   'rainforest.': 0.01,
#   'driest': 0.01,
#   'island': 0.01,
#   'fire': 0.02,
#   'Jollof': 0.01,
#   'warm': 0.01,
#   'tagine,': 0.01,
#   'braai.': 0.02,
#   'stew.': 0.01,
#   'local': 0.01,
#   'chicken,': 0.01,
#   'sun-drenched': 0.01,
#   'table,': 0.01,
#   'bounty': 0.01,
#   'day': 0.01,
#   'crispy,': 0.01,
#   "country's": 0.01,
#   'meal': 0.01,
#   'surrounding': 0.01,
#   "world's": 0.03,
#   'pharaohs.': 0.01,
#   'Fourth': 0.01,
#   'three': 0.01,
#   'ancient': 0.01,
#   'time,': 0.01,
#   'most': 0.04,
#   'city': 0.01,
#   'city,': 0.01,
#   'Serengeti.': 0.01,
#   'Medina,': 0.01,
#   'shopping': 0.01,
#   'textiles,': 0.01,
#   'fish,': 0.01,
#   'market': 0.01,
#   'vendors': 0.01,
#   'shoppers.': 0.01,
#   'small': 0.02,
#   'Tanzanian': 0.01,
#   'human': 0.01,
#   'clippers.': 0.01,
#   'Gambian': 0.01,
#   'ocean': 0.01,
#   'sea': 0.01,
#   'Djiboutian': 0.01,
#   'lake,': 0.01,
#   'Swazi': 0.01,
#   'largest': 0.04,
#   'Middle': 0.01,
#   'number': 0.01,
#   'continent,': 0.01,
#   'linguistic': 0.01,
#   'earliest': 0.01,
#   'Nok': 0.01,
#   'Makonde': 0.01,
#   'Dogon': 0.01,
#   'sculptures': 0.01,
#   'Yoruba': 0.01,
#   'Asante': 0.01,
#   'nutritional': 0.01,
#   'bread': 0.01,
#   'greens.': 0.01,
#   'baobab': 0.01,
#   'rooibos': 0.01,
#   'marula': 0.01,
#   'San': 0.01,
#   'African': 0.01,
#   'lake': 0.01,
#   'Chobe': 0.01,
#   'year.': 0.01,
#   'Big': 0.01,
#   'central': 0.01,
#   'eastern': 0.01,
#   'Great': 0.02,
#   'Sahara.': 0.01,
#   'Kalahari': 0.01,
#   'tallest': 0.01,
#   'Sahara': 0.01,
#   'tree': 0.01,
#   "jungle,'": 0.01,
#   'continent.': 0.01,
#   "'Big": 0.02,
#   'iconic': 0.01,
#   'Ethiopian': 0.01,
#   'males.': 0.01},
#  'the soul': {'of': 1.0},
#  'soul of': {'Lagos.': 1.0},
#  'The warm': {'evening': 1.0},
#  'warm evening': {'air': 1.0},
#  'evening air': {'in': 1.0},
#  'air in': {'Accra': 1.0},
#  'in Accra': {'was': 1.0},
#  'Accra was': {'filled': 1.0},
#  'was filled': {'with': 1.0},
#  'filled with': {'the': 0.3333333333333333,
#   'a': 0.26666666666666666,
#   'laughter': 0.06666666666666667,
#   'storytellers,': 0.06666666666666667,
#   'egg': 0.06666666666666667,
#   'savory': 0.06666666666666667,
#   'ice,': 0.06666666666666667,
#   'tender': 0.06666666666666667},
#  'the lilting': {'melodies': 1.0},
#  'lilting melodies': {'of': 1.0},
#  'melodies of': {'Highlife': 1.0},
#  'of Highlife': {'music.': 1.0},
#  'Highlife music.': {'At': 1.0},
#  'music. At': {'a': 1.0},
#  'At a': {'small': 0.5, 'bustling': 0.25, 'corner': 0.25},
#  'a small': {'bar': 0.0625,
#   'radio': 0.0625,
#   'township': 0.0625,
#   'village': 0.1875,
#   'well': 0.0625,
#   'coastal': 0.0625,
#   'plastic': 0.0625,
#   'restaurant,': 0.0625,
#   'food': 0.0625,
#   'cafe,': 0.0625,
#   'village,': 0.0625,
#   'diner': 0.0625,
#   'roadside': 0.0625,
#   'eatery': 0.0625},
#  'small bar': {'tucked': 1.0},
#  'bar tucked': {'away': 1.0},
#  'tucked away': {'on': 1.0},
#  'away on': {'a': 1.0},
#  'on a': {'side': 0.0625,
#   'stool': 0.0625,
#   'platter,': 0.125,
#   'large': 0.0625,
#   'bustling': 0.0625,
#   'hot': 0.1875,
#   'quest.': 0.0625,
#   'sweltering': 0.0625,
#   'warm': 0.0625,
#   'stick': 0.0625,
#   'bread': 0.0625,
#   'quest': 0.0625,
#   'cool': 0.0625},
#  'a side': {'street,': 0.16666666666666666,
#   'dish': 0.16666666666666666,
#   'of': 0.3333333333333333,
#   'to': 0.16666666666666666,
#   'dish.': 0.16666666666666666},
#  'side street,': {'a': 1.0},
#  'street, a': {'band': 1.0},
#  'a band': {'played,': 1.0},
#  'band played,': {'the': 1.0},
#  'played, the': {'guitars': 1.0},
#  'the guitars': {'weaving': 1.0},
#  'guitars weaving': {'intricate': 1.0},
#  'weaving intricate': {'patterns,': 0.5, 'melodies,': 0.5},
#  'intricate patterns,': {'the': 0.5, 'created': 0.5},
#  'patterns, the': {'horns': 1.0},
#  'horns adding': {'a': 1.0},
#  'adding a': {'bright,': 0.3333333333333333,
#   'layer': 0.3333333333333333,
#   'touch': 0.3333333333333333},
#  'a bright,': {'joyful': 1.0},
#  'bright, joyful': {'counterpoint.': 1.0},
#  'joyful counterpoint.': {'Kwame,': 1.0},
#  'counterpoint. Kwame,': {'a': 1.0},
#  'Kwame, a': {'man': 1.0},
#  'a man': {'with': 1.0},
#  'man with': {'a': 0.3333333333333333,
#   'boundless': 0.3333333333333333,
#   'weathered': 0.3333333333333333},
#  'with a': {'wistful': 0.016666666666666666,
#   'warm': 0.016666666666666666,
#   'powerful': 0.016666666666666666,
#   'distinct': 0.016666666666666666,
#   'semi-arid': 0.016666666666666666,
#   'desert': 0.016666666666666666,
#   'mischievous': 0.03333333333333333,
#   'slightly': 0.06666666666666667,
#   'kaleidoscope': 0.016666666666666666,
#   'bright': 0.016666666666666666,
#   'subtle': 0.016666666666666666,
#   'variety': 0.016666666666666666,
#   'smoky': 0.016666666666666666,
#   'boundless': 0.016666666666666666,
#   'gentle': 0.016666666666666666,
#   'generous': 0.016666666666666666,
#   'flavor': 0.016666666666666666,
#   'hearty': 0.03333333333333333,
#   'height': 0.016666666666666666,
#   'brightly': 0.016666666666666666,
#   'calm': 0.016666666666666666,
#   'few': 0.016666666666666666,
#   'thirst': 0.03333333333333333,
#   'complex': 0.016666666666666666,
#   'starchy': 0.016666666666666666,
#   'spicy': 0.03333333333333333,
#   'citrus': 0.016666666666666666,
#   'stew,': 0.016666666666666666,
#   'whole': 0.016666666666666666,
#   'side': 0.016666666666666666,
#   'sauce': 0.016666666666666666,
#   'mixture': 0.016666666666666666,
#   'drink.': 0.016666666666666666,
#   'crispy': 0.016666666666666666,
#   'flavorful': 0.016666666666666666,
#   'nutty': 0.016666666666666666,
#   'cup': 0.016666666666666666,
#   'slight': 0.016666666666666666,
#   'strong': 0.03333333333333333,
#   'sour,': 0.016666666666666666,
#   'creamy': 0.016666666666666666,
#   'comforting': 0.016666666666666666,
#   'name': 0.016666666666666666,
#   'stick': 0.016666666666666666,
#   'sweet': 0.016666666666666666,
#   'squeeze': 0.016666666666666666,
#   'smooth,': 0.016666666666666666,
#   'porridge-like': 0.016666666666666666,
#   'bit': 0.016666666666666666,
#   'hint': 0.016666666666666666,
#   'savory': 0.016666666666666666,
#   'diet': 0.016666666666666666},
#  'a wistful': {'smile,': 1.0},
#  'wistful smile,': {'sat': 1.0},
#  'smile, sat': {'at': 1.0},
#  'sat at': {'a': 1.0},
#  'at a': {'table': 0.05555555555555555,
#   'small': 0.16666666666666666,
#   'time.': 0.05555555555555555,
#   'slower': 0.1111111111111111,
#   'gentle': 0.05555555555555555,
#   'local': 0.16666666666666666,
#   'bustling': 0.16666666666666666,
#   'community': 0.05555555555555555,
#   'vibrant': 0.05555555555555555,
#   'neighborhood': 0.05555555555555555,
#   'family-run': 0.05555555555555555},
#  'a table': {'nursing': 0.5, 'laden': 0.5},
#  'table nursing': {'a': 1.0},
#  'nursing a': {'beer,': 1.0},
#  'a beer,': {'lost': 1.0},
#  'beer, lost': {'in': 1.0},
#  'lost in': {'the': 1.0},
#  'the music.': {'The': 1.0},
#  'music. The': {'Highlife': 0.3333333333333333,
#   'Soukous': 0.3333333333333333,
#   'Bunny': 0.3333333333333333},
#  'The Highlife': {'tunes': 1.0},
#  'Highlife tunes': {'evoked': 1.0},
#  'tunes evoked': {'memories': 1.0},
#  'evoked memories': {'of': 1.0},
#  'memories of': {'his': 1.0},
#  'of his': {'childhood,': 0.14285714285714285,
#   'roots,': 0.14285714285714285,
#   'heritage,': 0.14285714285714285,
#   "grandfather's": 0.14285714285714285,
#   'life.': 0.14285714285714285,
#   'home,': 0.14285714285714285,
#   'dreams,': 0.14285714285714285},
#  'his childhood,': {'of': 1.0},
#  'childhood, of': {'family': 1.0},
#  'of family': {'gatherings,': 0.3333333333333333,
#   'gatherings.': 0.3333333333333333,
#   'meals.': 0.3333333333333333},
#  'family gatherings,': {'of': 1.0},
#  'gatherings, of': {'dancing': 1.0},
#  'of dancing': {'under': 1.0},
#  'dancing under': {'the': 1.0},
#  'under the': {'stars.': 0.2, 'lid,': 0.2, 'African': 0.4, 'sun,': 0.2},
#  'the stars.': {'The': 1.0},
#  'stars. The': {'music': 1.0},
#  'a soundtrack': {'to': 1.0},
#  'soundtrack to': {'his': 1.0},
#  'to his': {'life,': 0.3333333333333333,
#   'stories': 0.3333333333333333,
#   'patients': 0.3333333333333333},
#  'his life,': {'a': 1.0},
#  'a reminder': {'of': 1.0},
#  'reminder of': {'his': 0.125,
#   'the': 0.375,
#   'home.': 0.125,
#   'her': 0.125,
#   'their': 0.125,
#   'cultural': 0.125},
#  'his roots,': {'a': 1.0},
#  'roots, a': {'source': 1.0},
#  'a source': {'of': 1.0},
#  'source of': {'comfort': 0.25,
#   'energy': 0.25,
#   'nourishment,': 0.25,
#   'water': 0.25},
#  'of comfort': {'and': 1.0},
#  'comfort and': {'joy': 1.0},
#  'and joy': {'in': 1.0},
#  'joy in': {'the': 1.0},
#  'the bustling': {'city.': 0.25, 'souks': 0.25, 'city': 0.25, 'street': 0.25},
#  'The bustling': {'streets': 1.0},
#  'bustling streets': {'of': 1.0},
#  'streets of': {'Lagos': 0.5, 'the': 0.5},
#  'of Lagos': {'were': 1.0},
#  'Lagos were': {'alive': 1.0},
#  'were alive': {'with': 1.0},
#  'alive with': {'the': 0.75, 'music': 0.25},
#  'the sounds': {'of': 1.0},
#  'sounds of': {'Juju': 0.25,
#   'Mbalax': 0.25,
#   'conversation,': 0.25,
#   'birdsong': 0.25},
#  'of Juju': {'music.': 1.0},
#  'Juju music.': {'From': 1.0},
#  'music. From': {'a': 1.0},
#  'From a': {'small': 0.5, 'nearby': 0.5},
#  'small radio': {'in': 1.0},
#  'radio in': {'a': 1.0},
#  'in a': {'market': 0.01818181818181818,
#   'community': 0.01818181818181818,
#   'subtropical': 0.01818181818181818,
#   'small': 0.03636363636363636,
#   'village': 0.01818181818181818,
#   'little': 0.01818181818181818,
#   'low': 0.01818181818181818,
#   'secret': 0.01818181818181818,
#   'Ghanaian': 0.01818181818181818,
#   'harmonious': 0.01818181818181818,
#   'bustling': 0.01818181818181818,
#   'mixture': 0.03636363636363636,
#   'rich': 0.07272727272727272,
#   'single': 0.01818181818181818,
#   'book,': 0.01818181818181818,
#   'rural': 0.01818181818181818,
#   'seemingly': 0.01818181818181818,
#   'chaotic': 0.01818181818181818,
#   'sharp,': 0.01818181818181818,
#   'forgotten': 0.01818181818181818,
#   'flavorful': 0.01818181818181818,
#   'dry': 0.01818181818181818,
#   'tangy': 0.01818181818181818,
#   'sunlit': 0.01818181818181818,
#   'creamy': 0.01818181818181818,
#   'mound': 0.03636363636363636,
#   'berbere': 0.01818181818181818,
#   'rich,': 0.03636363636363636,
#   'spiced': 0.03636363636363636,
#   'thin': 0.01818181818181818,
#   'broth': 0.01818181818181818,
#   'thick,': 0.01818181818181818,
#   'baking': 0.01818181818181818,
#   'cast-iron': 0.01818181818181818,
#   'fiery': 0.01818181818181818,
#   'peanut': 0.01818181818181818,
#   'milky-white': 0.01818181818181818,
#   'large': 0.01818181818181818,
#   'traditional': 0.03636363636363636,
#   'cozy': 0.01818181818181818,
#   'rounded': 0.01818181818181818,
#   'special': 0.01818181818181818,
#   'communal': 0.01818181818181818,
#   'container,': 0.01818181818181818,
#   'dish': 0.01818181818181818,
#   'lemon': 0.01818181818181818},
#  'a market': {'stall,': 1.0},
#  'market stall,': {'the': 0.5, 'she': 0.5},
#  'stall, the': {'distinctive': 0.5, 'aroma': 0.5},
#  'the distinctive': {'rhythms': 0.25,
#   'vocals': 0.25,
#   'aesthetic': 0.25,
#   'black': 0.25},
#  'distinctive rhythms': {'and': 1.0},
#  'rhythms and': {'vocals': 1.0},
#  'and vocals': {'of': 1.0},
#  'vocals of': {'King': 0.5, 'Youssou': 0.5},
#  'of King': {'Sunny': 1.0},
#  'King Sunny': {'Adé': 1.0},
#  'Sunny Adé': {'poured': 1.0},
#  'Adé poured': {'out,': 1.0},
#  'poured out,': {'drawing': 1.0},
#  'out, drawing': {'a': 1.0},
#  'drawing a': {'crowd': 1.0},
#  'a crowd': {'of': 1.0},
#  'crowd of': {'listeners.': 1.0},
#  'of listeners.': {'Mama': 1.0},
#  'listeners. Mama': {'Bisi,': 1.0},
#  'Mama Bisi,': {'a': 1.0},
#  'Bisi, a': {'woman': 1.0},
#  'a woman': {'with': 0.6666666666666666,
#   'named': 0.16666666666666666,
#   'skillfully': 0.16666666666666666},
#  'woman with': {'a': 0.75, 'boundless': 0.25},
#  'a warm': {'smile': 0.16666666666666666,
#   'smile,': 0.16666666666666666,
#   'cup': 0.16666666666666666,
#   'comfort': 0.16666666666666666,
#   'chapati': 0.16666666666666666,
#   'butter-cream': 0.16666666666666666},
#  'warm smile': {'and': 1.0},
#  'smile and': {'a': 0.3333333333333333,
#   'nimble': 0.3333333333333333,
#   'skillful': 0.3333333333333333},
#  'and a': {'contagious': 0.02,
#   'testament': 0.04,
#   'symbol': 0.02,
#   'proverb': 0.02,
#   'secret': 0.04,
#   'vibrant': 0.02,
#   'medley': 0.02,
#   'warm': 0.02,
#   'hint': 0.04,
#   'wealth': 0.02,
#   'love': 0.04,
#   'reminder': 0.02,
#   'spicy': 0.02,
#   'rich,': 0.02,
#   'taste': 0.08,
#   'sense': 0.02,
#   'natural': 0.02,
#   'thatched': 0.02,
#   'smoky,': 0.02,
#   'texture': 0.02,
#   'fresh': 0.02,
#   'unique': 0.02,
#   'soft,': 0.02,
#   'bit': 0.02,
#   'splash': 0.02,
#   'savory,': 0.02,
#   'nutritious': 0.02,
#   'creamy': 0.02,
#   'concentrated': 0.02,
#   'low': 0.04,
#   'tangy,': 0.02,
#   'balance': 0.02,
#   'sour,': 0.02,
#   'remarkable': 0.02,
#   'rich': 0.02,
#   'vast': 0.02,
#   'flagship': 0.02,
#   'reintroduced': 0.02,
#   'vital': 0.02,
#   'few': 0.02,
#   'member': 0.02,
#   'distinctive': 0.02},
#  'a contagious': {'laugh,': 1.0},
#  'contagious laugh,': {'tapped': 1.0},
#  'laugh, tapped': {'her': 1.0},
#  'tapped her': {'feet': 1.0},
#  'her feet': {'to': 1.0},
#  'feet to': {'the': 1.0},
#  'the beat': {'as': 1.0},
#  'beat as': {'she': 1.0},
#  'as she': {'haggled': 1.0},
#  'she haggled': {'for': 1.0},
#  'haggled for': {'vegetables.': 1.0},
#  'for vegetables.': {'The': 1.0},
#  'vegetables. The': {'music': 0.5, 'air': 0.5},
#  'a constant': {'companion': 0.5, 'negotiation': 0.5},
#  'constant companion': {'in': 1.0},
#  'companion in': {'her': 1.0},
#  'in her': {'life,': 0.3333333333333333,
#   'eyes': 0.3333333333333333,
#   'community.': 0.3333333333333333},
#  'her life,': {'a': 1.0},
#  'and inspiration,': {'a': 1.0},
#  'inspiration, a': {'reminder': 1.0},
#  'the rich': {'cultural': 0.4,
#   'tapestry': 0.1,
#   'spices,': 0.1,
#   'flavors': 0.1,
#   'sauce,': 0.1,
#   'history': 0.1,
#   'aroma': 0.1},
#  'rich cultural': {'tapestry': 0.25,
#   'heritage': 0.25,
#   'beliefs': 0.25,
#   'traditions': 0.25},
#  'cultural tapestry': {'of': 1.0},
#  'tapestry of': {'Nigeria.': 0.5, 'her': 0.5},
#  'The Dakar': {'waterfront': 1.0},
#  'Dakar waterfront': {'was': 1.0},
#  'waterfront was': {'buzzing': 1.0},
#  'was buzzing': {'with': 1.0},
#  'buzzing with': {'activity': 1.0},
#  'with activity': {'as': 1.0},
#  'activity as': {'the': 1.0},
#  'as the': {'sun': 0.15384615384615385,
#   'designs': 0.07692307692307693,
#   'Harmattan,': 0.07692307692307693,
#   'rich,': 0.07692307692307693,
#   'day': 0.07692307692307693,
#   'Zambezi': 0.07692307692307693,
#   'children,': 0.07692307692307693,
#   'eye': 0.07692307692307693,
#   'base,': 0.07692307692307693,
#   'longest': 0.07692307692307693,
#   'ancient': 0.07692307692307693,
#   'giant': 0.07692307692307693},
#  'the sun': {'began': 0.6666666666666666, 'dipped': 0.3333333333333333},
#  'sun began': {'to': 1.0},
#  'began to': {'set.': 0.6666666666666666, 'prepare': 0.3333333333333333},
#  'to set.': {'From': 0.5, 'At': 0.5},
#  'set. From': {'a': 1.0},
#  'a nearby': {'restaurant,': 0.5, 'village.': 0.5},
#  'nearby restaurant,': {'the': 1.0},
#  'restaurant, the': {'vibrant': 1.0},
#  'the vibrant': {'sounds': 0.16666666666666666,
#   'red': 0.16666666666666666,
#   'colors': 0.5,
#   'chatter': 0.16666666666666666},
#  'vibrant sounds': {'of': 1.0},
#  'of Mbalax': {'music': 1.0},
#  'Mbalax music': {'spilled': 1.0},
#  'music spilled': {'out,': 1.0},
#  'spilled out,': {'the': 1.0},
#  'out, the': {'distinctive': 1.0},
#  'distinctive vocals': {'of': 1.0},
#  'of Youssou': {"N'Dour": 1.0},
#  "Youssou N'Dour": {'soaring': 1.0},
#  "N'Dour soaring": {'over': 1.0},
#  'soaring over': {'the': 1.0},
#  'over the': {'complex': 0.14285714285714285,
#   'open': 0.14285714285714285,
#   'flames,': 0.14285714285714285,
#   'valleys': 0.14285714285714285,
#   'fluffy': 0.14285714285714285,
#   'mix.': 0.14285714285714285,
#   'pudding,': 0.14285714285714285},
#  'the complex': {'percussion': 0.3333333333333333,
#   'religious': 0.3333333333333333,
#   'linguistic': 0.3333333333333333},
#  'complex percussion': {'and': 1.0},
#  'percussion and': {'the': 1.0},
#  'the hypnotic': {'basslines.': 1.0},
#  'hypnotic basslines.': {'A': 1.0},
#  'basslines. A': {'group': 1.0},
#  'A group': {'of': 1.0},
#  'group of': {'friends,': 0.2, 'men': 0.4, 'friends': 0.2, 'primates': 0.2},
#  'of friends,': {'gathered': 1.0},
#  'friends, gathered': {'for': 1.0},
#  'gathered for': {'an': 1.0},
#  'for an': {'evening': 1.0},
#  'an evening': {'meal,': 1.0},
#  'evening meal,': {'swayed': 1.0},
#  'meal, swayed': {'to': 1.0},
#  'swayed to': {'the': 1.0},
#  'music, their': {'faces': 1.0},
#  'their faces': {'lit': 0.3333333333333333,
#   'illuminated': 0.3333333333333333,
#   'etched': 0.3333333333333333},
#  'faces lit': {'up': 1.0},
#  'lit up': {'with': 1.0},
#  'up with': {'smiles.': 0.5, 'bread.': 0.5},
#  'with smiles.': {'The': 1.0},
#  'smiles. The': {'Mbalax': 1.0},
#  'The Mbalax': {'rhythms,': 1.0},
#  'Mbalax rhythms,': {'a': 1.0},
#  'rhythms, a': {'blend': 0.5, 'fusion': 0.5},
#  'a blend': {'of': 1.0},
#  'blend of': {'traditional': 0.09090909090909091,
#   'spices': 0.18181818181818182,
#   'spices,': 0.18181818181818182,
#   'land': 0.09090909090909091,
#   'meat,': 0.09090909090909091,
#   'ground': 0.18181818181818182,
#   'green': 0.09090909090909091,
#   'spiced': 0.09090909090909091},
#  'of traditional': {'Senegalese': 1.0},
#  'traditional Senegalese': {'music': 1.0},
#  'Senegalese music': {'and': 1.0},
#  'music and': {'modern': 0.3333333333333333,
#   'laughter.': 0.3333333333333333,
#   'their': 0.3333333333333333},
#  'and modern': {'influences,': 1.0},
#  'modern influences,': {'created': 1.0},
#  'influences, created': {'an': 0.5, 'a': 0.5},
#  'created an': {'atmosphere': 1.0},
#  'an atmosphere': {'of': 1.0},
#  'atmosphere of': {'celebration': 1.0},
#  'of celebration': {'and': 1.0},
#  'celebration and': {'joy,': 1.0},
#  'and joy,': {'a': 1.0},
#  'joy, a': {'vibrant': 0.5, 'celebration': 0.5},
#  'of Senegalese': {'culture.': 0.5, 'hospitality,': 0.5},
#  'The Kinshasa': {'night': 1.0},
#  'Kinshasa night': {'was': 1.0},
#  'night was': {'alive': 1.0},
#  'was alive': {'with': 1.0},
#  'infectious energy': {'of': 1.0},
#  'energy of': {'Soukous': 0.5, 'a': 0.5},
#  'of Soukous': {'music.': 1.0},
#  'Soukous music.': {'In': 1.0},
#  'music. In': {'a': 1.0},
#  'In a': {'crowded': 0.2, 'small': 0.8},
#  'a crowded': {'nightclub,': 1.0},
#  'crowded nightclub,': {'the': 1.0},
#  'nightclub, the': {'band': 1.0},
#  'the band': {'played,': 1.0},
#  'intricate melodies,': {'the': 1.0},
#  'melodies, the': {'drums': 1.0},
#  'drums driving': {'the': 1.0},
#  'driving the': {'rhythm,': 1.0},
#  'the rhythm,': {'and': 1.0},
#  'rhythm, and': {'the': 1.0},
#  "the singers'": {'voices': 1.0},
#  "singers' voices": {'urging': 1.0},
#  'voices urging': {'everyone': 1.0},
#  'urging everyone': {'to': 1.0},
#  'everyone to': {'dance.': 1.0},
#  'to dance.': {'Jean-Pierre,': 1.0},
#  'dance. Jean-Pierre,': {'a': 1.0},
#  'Jean-Pierre, a': {'man': 1.0},
#  'with boundless': {'energy,': 0.5, 'energy': 0.5},
#  'boundless energy,': {'moved': 1.0},
#  'energy, moved': {'his': 1.0},
#  'moved his': {'feet': 1.0},
#  'his feet': {'to': 1.0},
#  'the beat,': {'lost': 1.0},
#  'beat, lost': {'in': 1.0},
#  'The Soukous': {'rhythms,': 1.0},
#  'Soukous rhythms,': {'a': 1.0},
#  'a fusion': {'of': 1.0},
#  'fusion of': {'Congolese': 1.0},
#  'of Congolese': {'rumba': 1.0},
#  'Congolese rumba': {'and': 1.0},
#  'rumba and': {'other': 1.0},
#  'and other': {'influences,': 0.1111111111111111,
#   'vegetables.': 0.1111111111111111,
#   'herbivores': 0.1111111111111111,
#   'words.': 0.1111111111111111,
#   'materials,': 0.1111111111111111,
#   'objects': 0.1111111111111111,
#   'cultural': 0.1111111111111111,
#   'healthier': 0.1111111111111111,
#   'preparations,': 0.1111111111111111},
#  'other influences,': {'created': 1.0},
#  'created a': {'whirlwind': 1.0},
#  'a whirlwind': {'of': 1.0},
#  'whirlwind of': {'movement': 1.0},
#  'of movement': {'and': 1.0},
#  'movement and': {'joy,': 1.0},
#  'of life': {'and': 0.4, 'under': 0.2, '-': 0.4},
#  'life and': {'music': 0.5, 'resilience': 0.5},
#  'and music': {'in': 1.0},
#  'music in': {'the': 1.0},
#  'the heart': {'of': 1.0},
#  'heart of': {'Africa.': 0.25, 'Nairobi,': 0.25, 'the': 0.25, 'Lagos,': 0.25},
#  'small township': {'outside': 1.0},
#  'township outside': {'Durban,': 1.0},
#  'outside Durban,': {'a': 1.0},
#  'Durban, a': {'group': 1.0},
#  'a group': {'of': 1.0},
#  'of men': {'gathered': 1.0},
#  'men gathered': {'in': 0.5, 'at': 0.5},
#  'gathered in': {'a': 1.0},
#  'a community': {'hall.': 0.5, 'gathering,': 0.5},
#  'community hall.': {'They': 1.0},
#  'hall. They': {'were': 1.0},
#  'They were': {'members': 0.3333333333333333,
#   'headed': 0.3333333333333333,
#   'hungry,': 0.3333333333333333},
#  'were members': {'of': 1.0},
#  'members of': {'an': 0.5, 'the': 0.5},
#  'of an': {'Isicathamiya': 0.25,
#   'ancient': 0.25,
#   'omelette': 0.25,
#   'Ethiopian': 0.25},
#  'an Isicathamiya': {'choir,': 1.0},
#  'Isicathamiya choir,': {'practicing': 1.0},
#  'choir, practicing': {'their': 1.0},
#  'practicing their': {'intricate': 1.0},
#  'their intricate': {'harmonies': 1.0},
#  'intricate harmonies': {'and': 1.0},
#  'harmonies and': {'synchronized': 1.0},
#  'and synchronized': {'dance': 1.0},
#  'synchronized dance': {'moves.': 1.0},
#  'dance moves.': {'The': 1.0},
#  'moves. The': {'music,': 1.0},
#  'The music,': {'characterized': 1.0},
#  'music, characterized': {'by': 1.0},
#  'characterized by': {'its': 0.2857142857142857,
#   'intricate': 0.07142857142857142,
#   'an': 0.07142857142857142,
#   'high': 0.07142857142857142,
#   'a': 0.2857142857142857,
#   'hot,': 0.07142857142857142,
#   'the': 0.07142857142857142,
#   'their': 0.07142857142857142},
#  'by its': {'a': 0.1,
#   'distinctive': 0.1,
#   'intricate': 0.1,
#   'sweet': 0.1,
#   'iconic': 0.2,
#   'massive,': 0.1,
#   'massive': 0.1,
#   'solid': 0.1,
#   'long': 0.1},
#  'its a': {'cappella': 1.0},
#  'a cappella': {'vocals': 1.0},
#  'cappella vocals': {'and': 1.0},
#  'vocals and': {'close': 1.0},
#  'and close': {'harmonies,': 1.0},
#  'close harmonies,': {'filled': 1.0},
#  'harmonies, filled': {'the': 1.0},
#  'filled the': {'hall': 0.14285714285714285,
#   'air,': 0.14285714285714285,
#   'air': 0.42857142857142855,
#   'small': 0.14285714285714285,
#   'air.': 0.14285714285714285},
#  'the hall': {'with': 1.0},
#  'hall with': {'a': 1.0},
#  'powerful and': {'moving': 1.0},
#  'and moving': {'sound.': 1.0},
#  'moving sound.': {'For': 1.0},
#  'sound. For': {'these': 1.0},
#  'For these': {'men,': 1.0},
#  'these men,': {'Isicathamiya': 1.0},
#  'men, Isicathamiya': {'was': 1.0},
#  'Isicathamiya was': {'more': 1.0},
#  'just music;': {'it': 1.0},
#  'music; it': {'was': 1.0},
#  'a way': {'to': 1.0},
#  'way to': {'express': 0.09090909090909091,
#   'start': 0.09090909090909091,
#   'rehydrate': 0.09090909090909091,
#   'quench': 0.18181818181818182,
#   'address': 0.09090909090909091,
#   'add': 0.09090909090909091,
#   'stay': 0.09090909090909091,
#   'combat': 0.09090909090909091,
#   'extend': 0.09090909090909091,
#   'cool': 0.09090909090909091},
#  'to express': {'their': 1.0},
#  'express their': {'emotions,': 1.0},
#  'their emotions,': {'to': 1.0},
#  'emotions, to': {'connect': 1.0},
#  'to connect': {'with': 1.0},
#  'connect with': {'their': 0.5, 'the': 0.5},
#  'with their': {'Zulu': 0.3333333333333333,
#   'surroundings.': 0.3333333333333333,
#   'fingers': 0.3333333333333333},
#  'their Zulu': {'heritage,': 1.0},
#  'Zulu heritage,': {'and': 1.0},
#  'heritage, and': {'to': 1.0},
#  'and to': {'find': 1.0},
#  'to find': {'solace': 1.0},
#  'find solace': {'and': 1.0},
#  'solace and': {'strength': 1.0},
#  'and strength': {'in': 1.0},
#  'strength in': {'the': 1.0},
#  'the face': {'of': 1.0},
#  'face of': {'adversity.': 1.0},
#  'The vibrant': {'colors': 0.3333333333333333, 'red': 0.6666666666666666},
#  'vibrant colors': {'and': 0.25, 'of': 0.75},
#  'colors and': {'intricate': 1.0},
#  'and intricate': {'patterns': 0.5, 'details,': 0.5},
#  'intricate patterns': {'of': 1.0},
#  'patterns of': {'Kente': 0.5, 'Adire': 0.5},
#  'of Kente': {'cloth,': 0.5, 'is': 0.5},
#  'Kente cloth,': {'a': 1.0},
#  'cloth, a': {'symbol': 1.0},
#  'a symbol': {'of': 1.0},
#  'symbol of': {'Ghanaian': 0.045454545454545456,
#   'Malian': 0.045454545454545456,
#   'cultural': 0.045454545454545456,
#   'East': 0.045454545454545456,
#   'African': 0.045454545454545456,
#   'home,': 0.045454545454545456,
#   'his': 0.045454545454545456,
#   'warmth,': 0.045454545454545456,
#   'family,': 0.045454545454545456,
#   'community,': 0.045454545454545456,
#   'her': 0.045454545454545456,
#   'Senegalese': 0.045454545454545456,
#   'their': 0.045454545454545456,
#   'community': 0.09090909090909091,
#   'resilience,': 0.045454545454545456,
#   'the': 0.045454545454545456,
#   'hospitality': 0.045454545454545456,
#   'ecological': 0.045454545454545456,
#   "Africa's": 0.045454545454545456,
#   'life': 0.045454545454545456,
#   'health': 0.045454545454545456},
#  'of Ghanaian': {'royalty': 0.3333333333333333,
#   'identity': 0.3333333333333333,
#   'culture.': 0.3333333333333333},
#  'Ghanaian royalty': {'and': 1.0},
#  'royalty and': {'prestige,': 1.0},
#  'and prestige,': {'tell': 1.0},
#  'prestige, tell': {'stories': 1.0},
#  'tell stories': {'of': 1.0},
#  'stories of': {'history,': 0.25,
#   'Malian': 0.25,
#   'desert': 0.25,
#   'their': 0.25},
#  'of history,': {'culture,': 1.0},
#  'history, culture,': {'and': 1.0},
#  'culture, and': {'social': 0.5, 'its': 0.5},
#  'and social': {'status.': 0.25,
#   'expression.': 0.25,
#   'gatherings.': 0.25,
#   'creature.': 0.25},
#  'social status.': {'Woven': 1.0},
#  'status. Woven': {'on': 1.0},
#  'Woven on': {'narrow': 1.0},
#  'on narrow': {'looms': 1.0},
#  'narrow looms': {'by': 1.0},
#  'looms by': {'skilled': 1.0},
#  'by skilled': {'artisans,': 1.0},
#  'skilled artisans,': {'each': 1.0},
#  'artisans, each': {'strip': 1.0},
#  'each strip': {'of': 1.0},
#  'strip of': {'Kente': 1.0},
#  'Kente is': {'a': 1.0},
#  'is a': {'testament': 0.027777777777777776,
#   'visual': 0.006944444444444444,
#   'textile': 0.006944444444444444,
#   'vibrant': 0.020833333333333332,
#   'celebration': 0.006944444444444444,
#   'beloved': 0.027777777777777776,
#   'symbol': 0.006944444444444444,
#   'vast': 0.020833333333333332,
#   'customary': 0.013888888888888888,
#   'refreshing': 0.006944444444444444,
#   'healthy': 0.013888888888888888,
#   'simple': 0.013888888888888888,
#   'hearty': 0.020833333333333332,
#   'popular': 0.0625,
#   'soft,': 0.006944444444444444,
#   'tangy': 0.006944444444444444,
#   'classic': 0.013888888888888888,
#   'filling': 0.013888888888888888,
#   'common': 0.006944444444444444,
#   'rich': 0.013888888888888888,
#   'traditional': 0.09722222222222222,
#   'savory': 0.013888888888888888,
#   'protein-rich,': 0.006944444444444444,
#   'light,': 0.006944444444444444,
#   'flavorful': 0.013888888888888888,
#   'Ghanaian': 0.006944444444444444,
#   'plate': 0.006944444444444444,
#   'dense': 0.006944444444444444,
#   'staple': 0.0625,
#   'favorite': 0.006944444444444444,
#   'spongy,': 0.006944444444444444,
#   'spicy': 0.020833333333333332,
#   'convenient,': 0.006944444444444444,
#   'green,': 0.006944444444444444,
#   'famous': 0.006944444444444444,
#   'fermented': 0.013888888888888888,
#   'firm,': 0.006944444444444444,
#   'slow-cooked': 0.006944444444444444,
#   'tender,': 0.006944444444444444,
#   'comforting,': 0.006944444444444444,
#   'North': 0.006944444444444444,
#   'crispy': 0.006944444444444444,
#   'warming': 0.006944444444444444,
#   'sweet': 0.013888888888888888,
#   'green': 0.013888888888888888,
#   'thick': 0.006944444444444444,
#   'tangy,': 0.006944444444444444,
#   'South': 0.006944444444444444,
#   'savory-sweet': 0.006944444444444444,
#   'communal': 0.006944444444444444,
#   'thick,': 0.006944444444444444,
#   'round,': 0.006944444444444444,
#   'baked': 0.006944444444444444,
#   'refreshing,': 0.006944444444444444,
#   'mildly': 0.006944444444444444,
#   'fruity': 0.006944444444444444,
#   'cloudy,': 0.006944444444444444,
#   'strong': 0.006944444444444444,
#   'creamy,': 0.013888888888888888,
#   'strong,': 0.006944444444444444,
#   'milky,': 0.006944444444444444,
#   'hot,': 0.013888888888888888,
#   'golden,': 0.006944444444444444,
#   'home-brewed': 0.006944444444444444,
#   'naturally': 0.013888888888888888,
#   'non-alcoholic': 0.006944444444444444,
#   'smooth,': 0.006944444444444444,
#   'creamy': 0.006944444444444444,
#   'vast,': 0.006944444444444444,
#   'major': 0.006944444444444444,
#   'premier': 0.006944444444444444,
#   'stronghold': 0.006944444444444444,
#   'world': 0.006944444444444444,
#   'sanctuary': 0.006944444444444444,
#   'UNESCO': 0.006944444444444444,
#   'land': 0.006944444444444444,
#   'historic': 0.006944444444444444,
#   'large': 0.020833333333333332,
#   'highly': 0.006944444444444444,
#   'large,': 0.020833333333333332,
#   'graceful,': 0.006944444444444444,
#   'habitat': 0.006944444444444444,
#   'specialized': 0.006944444444444444},
#  'a testament': {'to': 1.0},
#  'testament to': {'patience': 0.09090909090909091,
#   'the': 0.7272727272727273,
#   'its': 0.09090909090909091,
#   'how': 0.09090909090909091},
#  'to patience': {'and': 1.0},
#  'patience and': {'artistry.': 1.0},
#  'and artistry.': {'The': 1.0},
#  'artistry. The': {'geometric': 0.5, 'barbershop': 0.5},
#  'The geometric': {'designs,': 1.0},
#  'geometric designs,': {'rich': 0.3333333333333333,
#   'floral': 0.3333333333333333,
#   'have': 0.3333333333333333},
#  'designs, rich': {'with': 1.0},
#  'rich with': {'symbolism,': 1.0},
#  'with symbolism,': {'represent': 1.0},
#  'symbolism, represent': {'proverbs,': 1.0},
#  'represent proverbs,': {'historical': 0.5, 'stories,': 0.5},
#  'proverbs, historical': {'events,': 1.0},
#  'historical events,': {'and': 1.0},
#  'events, and': {'important': 1.0},
#  'and important': {'figures.': 1.0},
#  'important figures.': {'Worn': 1.0},
#  'figures. Worn': {'during': 1.0},
#  'Worn during': {'special': 1.0},
#  'during special': {'occasions': 1.0},
#  'special occasions': {'and': 1.0},
#  'occasions and': {'ceremonies,': 1.0},
#  'and ceremonies,': {'Kente': 0.3333333333333333,
#   'representing': 0.3333333333333333,
#   'embodying': 0.3333333333333333},
#  'ceremonies, Kente': {'cloth': 1.0},
#  'Kente cloth': {'embodies': 1.0},
#  'cloth embodies': {'the': 1.0},
#  'embodies the': {'spirit': 1.0},
#  'the spirit': {'of': 1.0},
#  'spirit of': {'Ghana,': 0.5, 'Senegal': 0.5},
#  'of Ghana,': {'its': 1.0},
#  'Ghana, its': {'vibrant': 1.0},
#  'its vibrant': {'culture,': 0.5, 'taste': 0.5},
#  'vibrant culture,': {'and': 1.0},
#  'and its': {'rich': 0.125,
#   'ability': 0.125,
#   'rhythms.': 0.125,
#   'nutritional': 0.125,
#   'remarkable': 0.125,
#   'fibrous': 0.125,
#   'versatile': 0.125,
#   'spotted': 0.125},
#  'its rich': {'history.': 1.0},
#  'rich history.': {'From': 1.0},
#  'history. From': {'the': 1.0},
#  'From the': {'bright': 0.3333333333333333,
#   'bold,': 0.3333333333333333,
#   'top,': 0.3333333333333333},
#  'the bright': {'yellows': 1.0},
#  'bright yellows': {'and': 1.0},
#  'yellows and': {'golds': 1.0},
#  'and golds': {'representing': 1.0},
#  'golds representing': {'royalty': 1.0},
#  'representing royalty': {'to': 1.0},
#  'royalty to': {'the': 1.0},
#  'the deep': {'blues': 0.5, 'connection': 0.5},
#  'deep blues': {'and': 1.0},
#  'blues and': {'greens': 1.0},
#  'and greens': {'symbolizing': 1.0},
#  'greens symbolizing': {'spirituality,': 1.0},
#  'symbolizing spirituality,': {'Kente': 1.0},
#  'spirituality, Kente': {'is': 1.0},
#  'a visual': {'language,': 1.0},
#  'visual language,': {'a': 1.0},
#  'language, a': {'wearable': 1.0},
#  'a wearable': {'expression': 1.0},
#  'wearable expression': {'of': 1.0},
#  'Ghanaian identity': {'and': 1.0},
#  'identity and': {'heritage.': 0.5, 'a': 0.5},
#  'Bogolanfini, or': {'mud': 1.0},
#  'or mud': {'cloth,': 1.0},
#  'mud cloth,': {'from': 1.0},
#  'cloth, from': {'Mali,': 1.0},
#  'from Mali,': {'is': 1.0},
#  'Mali, is': {'a': 0.5, 'closely': 0.5},
#  'a textile': {'steeped': 1.0},
#  'textile steeped': {'in': 1.0},
#  'steeped in': {'tradition': 1.0},
#  'in tradition': {'and': 1.0},
#  'tradition and': {'symbolism.': 1.0},
#  'and symbolism.': {'Its': 1.0},
#  'symbolism. Its': {'distinctive': 1.0},
#  'Its distinctive': {'patterns,': 0.5, 'plateau,': 0.5},
#  'distinctive patterns,': {'created': 1.0},
#  'patterns, created': {'using': 1.0},
#  'created using': {'fermented': 0.3333333333333333,
#   'various': 0.3333333333333333,
#   'a': 0.3333333333333333},
#  'using fermented': {'mud': 1.0},
#  'fermented mud': {'and': 1.0},
#  'mud and': {'natural': 1.0},
#  'and natural': {'dyes,': 0.5, 'beauty': 0.5},
#  'natural dyes,': {'tell': 1.0},
#  'dyes, tell': {'stories': 1.0},
#  'of Malian': {'culture,': 0.5, 'identity': 0.5},
#  'Malian culture,': {'history,': 1.0},
#  'culture, history,': {'and': 1.0},
#  'history, and': {'beliefs.': 1.0},
#  'and beliefs.': {'The': 1.0},
#  'beliefs. The': {'process': 1.0},
#  'The process': {'of': 0.3333333333333333,
#   'began': 0.3333333333333333,
#   'involves': 0.3333333333333333},
#  'process of': {'creating': 0.5, 'wax-resist': 0.5},
#  'of creating': {'Bogolanfini': 1.0},
#  'creating Bogolanfini': {'is': 1.0},
#  'Bogolanfini is': {'as': 1.0},
#  'is as': {'rich': 0.5, 'much': 0.5},
#  'as rich': {'and': 1.0},
#  'rich and': {'complex': 0.25,
#   'peanut-infused,': 0.25,
#   'spicy': 0.25,
#   'spiced': 0.25},
#  'and complex': {'as': 1.0},
#  'complex as': {'the': 1.0},
#  'the designs': {'themselves,': 1.0},
#  'designs themselves,': {'involving': 1.0},
#  'themselves, involving': {'multiple': 1.0},
#  'involving multiple': {'stages': 1.0},
#  'multiple stages': {'of': 1.0},
#  'stages of': {'dyeing,': 0.5, 'life.': 0.5},
#  'of dyeing,': {'painting,': 1.0},
#  'dyeing, painting,': {'and': 1.0},
#  'painting, and': {'sun-drying.': 1.0},
#  'and sun-drying.': {'Each': 1.0},
#  'sun-drying. Each': {'piece': 1.0},
#  'Each piece': {'is': 1.0},
#  'piece is': {'unique,': 1.0},
#  'is unique,': {'reflecting': 0.5, 'much': 0.5},
#  'unique, reflecting': {'the': 1.0},
#  'reflecting the': {'artistry': 0.1,
#   'advanced': 0.1,
#   'adaptation': 0.1,
#   'legacy': 0.1,
#   'linguistic': 0.1,
#   'rich': 0.1,
#   'deep': 0.1,
#   'social': 0.1,
#   'cultural': 0.1,
#   'cooking': 0.1},
#  'the artistry': {'and': 1.0},
#  'artistry and': {'skill': 0.5, 'a': 0.5},
#  'and skill': {'of': 1.0},
#  'skill of': {'the': 1.0},
#  'the maker.': {'Traditionally': 1.0},
#  'maker. Traditionally': {'worn': 1.0},
#  'Traditionally worn': {'by': 1.0},
#  'worn by': {'hunters': 0.5, 'women': 0.5},
#  'by hunters': {'and': 1.0},
#  'hunters and': {'warriors,': 1.0},
#  'and warriors,': {'Bogolanfini': 1.0},
#  'warriors, Bogolanfini': {'has': 1.0},
#  'Bogolanfini has': {'become': 1.0},
#  'has become': {'a': 0.6666666666666666, 'deeply': 0.3333333333333333},
#  'become a': {'symbol': 1.0},
#  'Malian identity': {'and': 1.0},
#  'the enduring': {'power': 0.5, 'human': 0.5},
#  'enduring power': {'of': 1.0},
#  'power of': {'indigenous': 0.16666666666666666,
#   'language': 0.16666666666666666,
#   'cross-cultural': 0.16666666666666666,
#   'shared': 0.16666666666666666,
#   'literacy': 0.16666666666666666,
#   'plain': 0.16666666666666666},
#  'of indigenous': {'art': 1.0},
#  'indigenous art': {'forms.': 1.0},
#  'Adire, a': {'resist-dyed': 1.0},
#  'a resist-dyed': {'indigo': 1.0},
#  'resist-dyed indigo': {'cloth': 1.0},
#  'indigo cloth': {'from': 1.0},
#  'cloth from': {'Nigeria,': 0.5, 'East': 0.5},
#  'from Nigeria,': {'is': 0.6666666666666666,
#   'particularly': 0.3333333333333333},
#  'Nigeria, is': {'a': 0.5, 'renowned': 0.5},
#  'of Yoruba': {'culture': 0.25,
#   'cosmology.': 0.25,
#   'women,': 0.25,
#   'artistry': 0.25},
#  'Yoruba culture': {'and': 1.0},
#  'culture and': {'creativity.': 0.5, 'a': 0.5},
#  'and creativity.': {'The': 1.0},
#  'creativity. The': {'intricate': 1.0},
#  'The intricate': {'patterns,': 1.0},
#  'using various': {'techniques': 1.0},
#  'various techniques': {'such': 1.0},
#  'techniques such': {'as': 1.0},
#  'such as': {'stitching,': 0.043478260869565216,
#   'carrots,': 0.043478260869565216,
#   'white-water': 0.043478260869565216,
#   'lions,': 0.043478260869565216,
#   'Maasai,': 0.043478260869565216,
#   'English,': 0.043478260869565216,
#   'carbohydrates,': 0.043478260869565216,
#   'fish,': 0.043478260869565216,
#   'meat,': 0.043478260869565216,
#   'activity': 0.043478260869565216,
#   'unsweetened': 0.043478260869565216,
#   'spinach': 0.043478260869565216,
#   'cumin,': 0.13043478260869565,
#   'onions,': 0.043478260869565216,
#   'salt,': 0.043478260869565216,
#   'ginger': 0.043478260869565216,
#   'ginger,': 0.043478260869565216,
#   'teff,': 0.043478260869565216,
#   'the': 0.08695652173913043,
#   'that': 0.043478260869565216},
#  'as stitching,': {'tying,': 1.0},
#  'stitching, tying,': {'and': 1.0},
#  'tying, and': {'applying': 1.0},
#  'and applying': {'starch': 0.5, 'this': 0.5},
#  'applying starch': {'paste,': 1.0},
#  'starch paste,': {'represent': 1.0},
#  'paste, represent': {'proverbs,': 1.0},
#  'proverbs, stories,': {'and': 1.0},
# ...
#  'Adire Oniko,': {'Adire': 1.0},
#  'Oniko, Adire': {'cloth': 1.0},
#  'Adire cloth': {'is': 1.0},
#  'cloth is': {'a': 1.0},
#  'Yoruba artistry': {'and': 1.0},
#  'of cultural': {'pride.': 0.5, 'heritage': 0.5},
#  'Kanga, a': {'colorful': 1.0},
#  'a colorful': {'printed': 0.5, 'and': 0.5},
#  'colorful printed': {'cloth': 1.0},
#  'printed cloth': {'from': 1.0},
#  'from East': {'Africa,': 1.0},
#  'East Africa,': {'particularly': 0.4,
#   'Central': 0.2,
#   'especially': 0.2,
#   'vendors': 0.2},
#  'Africa, particularly': {'Tanzania': 0.25, 'in': 0.5, 'Kenya': 0.25},
#  'particularly Tanzania': {'and': 1.0},
#  'Tanzania and': {'Kenya,': 0.5, 'Mozambique,': 0.5},
#  'and Kenya,': {'is': 1.0},
#  'Kenya, is': {'more': 1.0},
#  'is more': {'than': 1.0},
#  'just a': {'fabric;': 0.16666666666666666,
#   'meal;': 0.3333333333333333,
#   'meal,': 0.16666666666666666,
#   'place': 0.16666666666666666,
#   'drink': 0.16666666666666666},
#  'a fabric;': {"it's": 1.0},
#  "fabric; it's": {'a': 1.0},
#  "it's a": {'form': 0.3333333333333333,
#   'nutritious': 0.3333333333333333,
#   'commercial': 0.3333333333333333},
#  'a form': {'of': 1.0},
#  'form of': {'communication': 1.0},
#  'of communication': {'and': 1.0},
#  'communication and': {'social': 1.0},
#  'social expression.': {'Each': 1.0},
#  'expression. Each': {'Kanga': 1.0},
#  'Each Kanga': {'features': 1.0},
#  'Kanga features': {'a': 1.0},
#  'features a': {'central': 1.0},
#  'a central': {'design': 0.5, 'role': 0.5},
#  'central design': {'surrounded': 1.0},
#  'design surrounded': {'by': 1.0},
#  'surrounded by': {'a': 1.0},
#  'by a': {'border': 0.09090909090909091,
#   'hot,': 0.09090909090909091,
#   'tropical': 0.09090909090909091,
#   'burst': 0.09090909090909091,
#   'street': 0.18181818181818182,
#   'rotating': 0.09090909090909091,
#   'complex': 0.09090909090909091,
#   'system': 0.09090909090909091,
#   'savory': 0.09090909090909091,
#   'spicy': 0.09090909090909091},
#  'a border': {'and': 1.0},
#  'border and': {'a': 1.0},
#  'a proverb': {'or': 1.0},
#  'proverb or': {'saying,': 1.0},
#  'or saying,': {'often': 1.0},
#  'saying, often': {'written': 1.0},
#  'often written': {'in': 1.0},
#  'written in': {'Swahili.': 1.0},
#  'in Swahili.': {'These': 1.0},
#  'Swahili. These': {'proverbs': 1.0},
#  'These proverbs': {'offer': 1.0},
#  'proverbs offer': {'advice,': 1.0},
#  'offer advice,': {'commentary': 1.0},
#  'advice, commentary': {'on': 1.0},
#  'commentary on': {'social': 1.0},
#  'on social': {'issues,': 1.0},
#  'social issues,': {'or': 1.0},
#  'issues, or': {'expressions': 1.0},
#  'or expressions': {'of': 1.0},
#  'expressions of': {'love': 1.0},
#  'of love': {'and': 1.0},
#  'love and': {'friendship.': 1.0},
#  'and friendship.': {'Kanga': 1.0},
#  'friendship. Kanga': {'are': 1.0},
#  'Kanga are': {'worn': 1.0},
#  'are worn': {'by': 1.0},
#  'by women': {'for': 1.0},
#  'women for': {'everyday': 1.0},
#  'for everyday': {'wear,': 0.5, 'hydration,': 0.5},
#  'everyday wear,': {'special': 1.0},
#  'wear, special': {'occasions,': 1.0},
#  'special occasions,': {'and': 0.5, 'Swahili': 0.5},
#  'occasions, and': {'as': 1.0},
#  'and as': {'gifts,': 0.5, 'a': 0.5},
#  'as gifts,': {'serving': 1.0},
#  'gifts, serving': {'as': 1.0},
#  'serving as': {'a': 1.0},
#  'as a': {'vibrant': 0.03333333333333333,
#   'potjie,': 0.03333333333333333,
#   'sacred': 0.03333333333333333,
#   'group': 0.03333333333333333,
#   'soothing': 0.06666666666666667,
#   'warm': 0.03333333333333333,
#   'quick': 0.06666666666666667,
#   'breakfast': 0.06666666666666667,
#   'street': 0.03333333333333333,
#   'peanut': 0.03333333333333333,
#   'side': 0.06666666666666667,
#   'base': 0.03333333333333333,
#   'street-side': 0.03333333333333333,
#   'refreshing': 0.06666666666666667,
#   'light': 0.03333333333333333,
#   'natural': 0.03333333333333333,
#   'daily': 0.03333333333333333,
#   'nutritious': 0.03333333333333333,
#   'family': 0.03333333333333333,
#   'UNESCO': 0.03333333333333333,
#   'vital': 0.03333333333333333,
#   'global': 0.03333333333333333,
#   'powerful': 0.03333333333333333,
#   'metaphor': 0.03333333333333333,
#   'primary': 0.03333333333333333},
#  'vibrant symbol': {'of': 1.0},
#  'of East': {'African': 0.25,
#   'Africa.': 0.25,
#   'Africa,': 0.25,
#   'Africa': 0.25},
#  'East African': {'culture': 0.16666666666666666,
#   'Highlands': 0.16666666666666666,
#   'landscape': 0.16666666666666666,
#   'barbecue': 0.16666666666666666,
#   'fried': 0.16666666666666666,
#   'Rift': 0.16666666666666666},
#  'African culture': {'and': 1.0},
#  'the power': {'of': 0.6666666666666666, 'and': 0.3333333333333333},
#  'of language': {'and': 1.0},
#  'language and': {'visual': 1.0},
#  'and visual': {'expression.': 1.0},
#  'Ankara, also': {'known': 1.0},
#  'also known': {'as': 0.8, 'for': 0.2},
#  'known as': {'African': 0.1111111111111111,
#   'the': 0.1111111111111111,
#   'a': 0.1111111111111111,
#   "'Mosi-oa-Tunya'": 0.1111111111111111,
#   'groundnut': 0.1111111111111111,
#   'cassava': 0.1111111111111111,
#   'piri-piri),': 0.1111111111111111,
#   'Suya,': 0.1111111111111111,
#   'Lake': 0.1111111111111111},
#  'as African': {'wax': 1.0},
#  'African wax': {'print': 1.0},
#  'wax print': {'fabric,': 1.0},
#  'print fabric,': {'is': 1.0},
#  'fabric, is': {'a': 1.0},
#  'vibrant and': {'versatile': 0.5, 'energetic': 0.5},
#  'and versatile': {'textile': 1.0},
#  'versatile textile': {'popular': 1.0},
#  'textile popular': {'across': 1.0},
#  'popular across': {'Africa': 1.0},
#  'across Africa': {'and': 1.0},
#  'Africa and': {'beyond.': 0.5, 'the': 0.25, 'spanning': 0.25},
#  'and beyond.': {'Its': 1.0},
#  'beyond. Its': {'bold,': 1.0},
#  'Its bold,': {'colorful': 1.0},
#  'bold, colorful': {'patterns,': 1.0},
#  'colorful patterns,': {'often': 1.0},
#  'patterns, often': {'featuring': 1.0},
#  'often featuring': {'geometric': 1.0},
#  'featuring geometric': {'designs,': 1.0},
#  'designs, floral': {'motifs,': 1.0},
#  'floral motifs,': {'and': 1.0},
#  'motifs, and': {'intricate': 1.0},
#  'intricate details,': {'are': 1.0},
#  'details, are': {'produced': 1.0},
#  'are produced': {'through': 0.5, 'by': 0.5},
#  'produced through': {'a': 1.0},
#  'through a': {'complex': 1.0},
#  'complex process': {'of': 1.0},
#  'of wax-resist': {'dyeing.': 1.0},
#  'wax-resist dyeing.': {'While': 1.0},
#  'dyeing. While': {'not': 1.0},
#  'While not': {'originally': 1.0},
#  'not originally': {'from': 1.0},
#  'originally from': {'Africa,': 1.0},
#  'from Africa,': {'Ankara': 1.0},
#  'Africa, Ankara': {'has': 1.0},
#  'Ankara has': {'become': 1.0},
#  'of African': {'fashion': 0.16666666666666666,
#   'fashion.': 0.16666666666666666,
#   'sign': 0.16666666666666666,
#   'history.': 0.16666666666666666,
#   'tourism': 0.16666666666666666,
#   'wild': 0.16666666666666666},
#  'African fashion': {'and': 1.0},
#  'fashion and': {'cultural': 1.0},
#  'and cultural': {'expression,': 0.14285714285714285,
#   'identity.': 0.14285714285714285,
#   'heritage': 0.14285714285714285,
#   'exchanges': 0.14285714285714285,
#   'diffusion': 0.14285714285714285,
#   'variations': 0.14285714285714285,
#   'legacy.': 0.14285714285714285},
#  'cultural expression,': {'adapted': 1.0},
#  'expression, adapted': {'and': 1.0},
#  'adapted and': {'embraced': 1.0},
#  'and embraced': {'by': 1.0},
#  'embraced by': {'diverse': 1.0},
#  'by diverse': {'communities.': 1.0},
#  'diverse communities.': {'Its': 1.0},
#  'communities. Its': {'versatility': 1.0},
#  'Its versatility': {'allows': 1.0},
#  'versatility allows': {'for': 1.0},
#  'allows for': {'a': 1.0},
#  'for a': {'wide': 0.03225806451612903,
#   'closer': 0.03225806451612903,
#   'hot': 0.03225806451612903,
#   'comforting': 0.03225806451612903,
#   'plate': 0.0967741935483871,
#   'serving': 0.06451612903225806,
#   'steaming': 0.03225806451612903,
#   'refreshing': 0.06451612903225806,
#   'cup': 0.06451612903225806,
#   'glass': 0.06451612903225806,
#   'taste': 0.03225806451612903,
#   'chilled': 0.03225806451612903,
#   'common': 0.03225806451612903,
#   'hearty': 0.06451612903225806,
#   'touch': 0.03225806451612903,
#   'sweet': 0.03225806451612903,
#   'bowl': 0.06451612903225806,
#   'few': 0.03225806451612903,
#   'quick,': 0.03225806451612903,
#   'way': 0.03225806451612903,
#   'host': 0.03225806451612903,
#   'remote': 0.03225806451612903,
#   'reptile,': 0.03225806451612903},
#  'a wide': {'range': 0.6, 'spectrum': 0.2, 'array': 0.2},
#  'wide range': {'of': 1.0},
#  'range of': {'styles': 0.2,
#   'climates,': 0.2,
#   'plant': 0.2,
#   'flora': 0.2,
#   'habitats,': 0.2},
#  'of styles': {'and': 1.0},
#  'styles and': {'garments,': 1.0},
#  'and garments,': {'reflecting': 1.0},
#  'garments, reflecting': {'individual': 1.0},
#  'reflecting individual': {'creativity': 1.0},
#  'individual creativity': {'and': 1.0},
#  'creativity and': {'cultural': 1.0},
#  'cultural identity.': {'Ankara': 1.0},
#  'identity. Ankara': {'is': 1.0},
#  'Ankara is': {'a': 1.0},
#  'of cross-cultural': {'exchange': 1.0},
#  'cross-cultural exchange': {'and': 1.0},
#  'exchange and': {'the': 1.0},
#  'the dynamic': {'evolution': 1.0},
#  'dynamic evolution': {'of': 1.0},
#  'evolution of': {'African': 1.0},
#  'Shweshwe, a': {'printed': 1.0},
#  'a printed': {'cotton': 1.0},
#  'printed cotton': {'fabric': 1.0},
#  'cotton fabric': {'characterized': 1.0},
#  'fabric characterized': {'by': 1.0},
#  'by intricate': {'geometric': 1.0},
#  'intricate geometric': {'patterns,': 0.5, 'designs,': 0.5},
#  'geometric patterns,': {'is': 1.0},
#  'patterns, is': {'a': 1.0},
#  'a beloved': {'textile': 0.25, 'West': 0.25, 'dish': 0.25, 'staple': 0.25},
#  'beloved textile': {'in': 1.0},
#  'textile in': {'Southern': 1.0},
#  'in Southern': {'Africa,': 0.4, 'Africa.': 0.4, 'Africa': 0.2},
#  'Southern Africa,': {'particularly': 0.25,
#   'and': 0.25,
#   'especially': 0.25,
#   'extending': 0.25},
#  'particularly in': {'Lesotho': 0.5, 'savanna': 0.5},
#  'in Lesotho': {'and': 1.0},
#  'Lesotho and': {'South': 1.0},
#  'and South': {'Africa.': 1.0},
#  'South Africa.': {'Originally': 0.3333333333333333,
#   'The': 0.3333333333333333,
#   'Its': 0.3333333333333333},
#  'Africa. Originally': {'introduced': 1.0},
#  'Originally introduced': {'by': 1.0},
#  'introduced by': {'German': 1.0},
#  'by German': {'settlers': 1.0},
#  'German settlers': {'in': 1.0},
#  'settlers in': {'the': 1.0},
#  'the 19th': {'century,': 1.0},
#  '19th century,': {'it': 1.0},
#  'century, it': {'has': 1.0},
#  'it has': {'become': 0.5, 'a': 0.5},
#  'become deeply': {'ingrained': 1.0},
#  'deeply ingrained': {'in': 1.0},
#  'ingrained in': {'local': 1.0},
#  'in local': {'cultures,': 1.0},
#  'local cultures,': {'evolving': 1.0},
#  'cultures, evolving': {'into': 1.0},
#  'evolving into': {'a': 1.0},
#  'a unique': {'and': 0.3,
#   'ecosystem,': 0.1,
#   'perspective': 0.1,
#   'taste': 0.1,
#   'earthy': 0.1,
#   'dish': 0.1,
#   'smoky': 0.1,
#   'Afro-alpine': 0.1},
#  'unique and': {'distinctive': 0.3333333333333333,
#   'fulfilling': 0.3333333333333333,
#   'ancient': 0.3333333333333333},
#  'and distinctive': {'fabric.': 1.0},
#  'distinctive fabric.': {"Shweshwe's": 1.0},
#  "fabric. Shweshwe's": {'vibrant': 1.0},
#  "Shweshwe's vibrant": {'indigo,': 1.0},
#  'vibrant indigo,': {'brown,': 1.0},
#  'indigo, brown,': {'and': 1.0},
#  'brown, and': {'red': 1.0},
#  'and red': {'hues,': 1.0},
#  'red hues,': {'along': 1.0},
#  'hues, along': {'with': 1.0},
#  'along with': {'its': 0.2,
#   'vegetables': 0.2,
#   'essential': 0.2,
#   'an': 0.2,
#   'spices': 0.2},
#  'with its': {'intricate': 1.0},
#  'its intricate': {'geometric': 0.5, 'carvings,': 0.5},
#  'designs, have': {'made': 1.0},
#  'have made': {'it': 1.0},
#  'made it': {'a': 1.0},
#  'it a': {'popular': 0.10526315789473684,
#   'hotspot': 0.05263157894736842,
#   'valuable': 0.05263157894736842,
#   'paradise': 0.05263157894736842,
#   'delicious': 0.05263157894736842,
#   'vibrant': 0.05263157894736842,
#   'hearty': 0.05263157894736842,
#   'reddish-brown': 0.05263157894736842,
#   'brown': 0.05263157894736842,
#   'thick': 0.05263157894736842,
#   'fragrant': 0.05263157894736842,
#   'favored': 0.05263157894736842,
#   'distinct': 0.05263157894736842,
#   'premier': 0.05263157894736842,
#   'cornerstone': 0.05263157894736842,
#   'classic': 0.05263157894736842,
#   'true': 0.05263157894736842,
#   'food': 0.05263157894736842},
#  'a popular': {'choice': 0.07142857142857142,
#   'Nigerian': 0.07142857142857142,
#   'Ghanaian': 0.07142857142857142,
#   'local': 0.07142857142857142,
#   'West': 0.14285714285714285,
#   'Ugandan': 0.07142857142857142,
#   'East': 0.07142857142857142,
#   'breakfast': 0.07142857142857142,
#   'Southern': 0.07142857142857142,
#   'staple': 0.07142857142857142,
#   'cocktail': 0.07142857142857142,
#   'hibiscus': 0.07142857142857142,
#   'goal': 0.07142857142857142},
#  'popular choice': {'for': 1.0},
#  'choice for': {'traditional': 0.5, 'hydration,': 0.5},
#  'for traditional': {'garments,': 1.0},
#  'traditional garments,': {'contemporary': 1.0},
#  'garments, contemporary': {'fashion,': 1.0},
#  'contemporary fashion,': {'and': 1.0},
#  'fashion, and': {'home': 1.0},
#  'and home': {'décor.': 1.0},
#  'home décor.': {'The': 1.0},
#  'décor. The': {"fabric's": 1.0},
#  "The fabric's": {'enduring': 1.0},
#  "fabric's enduring": {'popularity': 1.0},
#  'enduring popularity': {'is': 1.0},
#  'popularity is': {'a': 1.0},
#  'to its': {'beauty,': 0.2,
#   'diverse': 0.2,
#   'distinctive': 0.2,
#   'unique': 0.2,
#   'exceptionally': 0.2},
#  'its beauty,': {'versatility,': 0.5, 'Musa': 0.5},
#  'beauty, versatility,': {'and': 1.0},
#  'versatility, and': {'its': 1.0},
#  'its ability': {'to': 1.0},
#  'ability to': {'represent': 0.5, 'adapt': 0.5},
#  'to represent': {'cultural': 1.0},
#  'represent cultural': {'heritage': 1.0},
#  'cultural heritage': {'and': 0.25, 'of': 0.5, 'amidst': 0.25},
#  'heritage and': {'identity.': 0.5, 'their': 0.5},
#  'The Sahara': {'Desert': 1.0},
#  'Sahara Desert': {'is': 0.5, 'and': 0.5},
#  'Desert is': {'characterized': 1.0},
#  'is characterized': {'by': 1.0},
#  'by an': {'extremely': 1.0},
#  'an extremely': {'arid': 1.0},
#  'extremely arid': {'climate,': 1.0},
#  'arid climate,': {'with': 1.0},
#  'climate, with': {'scorching': 0.25,
#   'warm': 0.25,
#   'high': 0.25,
#   'cooler': 0.25},
#  'with scorching': {'hot': 1.0},
#  'scorching hot': {'days': 1.0},
#  'hot days': {'and': 1.0},
#  'days and': {'surprisingly': 1.0},
#  'and surprisingly': {'cold': 1.0},
#  'surprisingly cold': {'nights.': 1.0},
#  'cold nights.': {'Rainfall': 1.0},
#  'nights. Rainfall': {'is': 1.0},
#  'Rainfall is': {'scarce': 0.3333333333333333,
#   'heavy': 0.3333333333333333,
#   'concentrated': 0.3333333333333333},
#  'is scarce': {'and': 1.0},
#  'scarce and': {'unpredictable,': 1.0},
#  'and unpredictable,': {'with': 1.0},
#  'unpredictable, with': {'some': 1.0},
#  'with some': {'areas': 0.6666666666666666, 'individuals': 0.3333333333333333},
#  'some areas': {'receiving': 0.5, 'experiencing': 0.5},
#  'areas receiving': {'less': 1.0},
#  'receiving less': {'than': 1.0},
#  'less than': {'25': 1.0},
#  'than 25': {'millimeters': 1.0},
#  '25 millimeters': {'(1': 1.0},
#  'millimeters (1': {'inch)': 1.0},
#  '(1 inch)': {'annually.': 1.0},
#  'inch) annually.': {'Temperatures': 1.0},
#  'annually. Temperatures': {'can': 1.0},
#  'Temperatures can': {'soar': 1.0},
#  'can soar': {'above': 1.0},
#  'soar above': {'50°C': 1.0},
#  'above 50°C': {'(122°F)': 1.0},
#  '50°C (122°F)': {'during': 1.0},
#  '(122°F) during': {'the': 1.0},
#  'during the': {'day,': 0.25, 'dry': 0.25, 'long': 0.5},
#  'the day,': {'while': 0.3333333333333333,
#   'especially': 0.3333333333333333,
#   'adding': 0.3333333333333333},
#  'day, while': {'at': 1.0},
#  'while at': {'night,': 1.0},
#  'at night,': {'the': 1.0},
#  'night, the': {'lack': 1.0},
#  'the lack': {'of': 1.0},
#  'lack of': {'cloud': 0.5, 'seasonal': 0.5},
#  'of cloud': {'cover': 1.0},
#  'cloud cover': {'allows': 1.0},
#  'cover allows': {'heat': 1.0},
#  'allows heat': {'to': 1.0},
#  'heat to': {'escape': 1.0},
#  'to escape': {'rapidly,': 1.0},
#  'escape rapidly,': {'causing': 1.0},
#  'rapidly, causing': {'temperatures': 1.0},
#  'causing temperatures': {'to': 1.0},
#  'temperatures to': {'plummet,': 1.0},
#  'to plummet,': {'sometimes': 1.0},
#  'plummet, sometimes': {'even': 1.0},
#  'sometimes even': {'below': 1.0},
#  'even below': {'freezing.': 1.0},
#  'below freezing.': {'Strong': 1.0},
#  'freezing. Strong': {'winds,': 1.0},
#  'Strong winds,': {'known': 1.0},
#  'winds, known': {'as': 1.0},
#  'the Harmattan,': {'often': 1.0},
#  'Harmattan, often': {'carry': 1.0},
#  'often carry': {'dust': 1.0},
#  'carry dust': {'and': 1.0},
#  ...}

# %% [markdown]
# To gain an understanding of the patterns that the model learned, inspect a few probability distributions.

# %%
print(f"P(B | \"as it\") = {trigram_model['as it']}")

print(f"P(B | \"as they\") = {trigram_model['as they']}")
# Out:
# P(B | "as it") = {'is': 0.6666666666666666, 'receives': 0.3333333333333333}
# P(B | "as they") = {'were': 1.0}

# %% [markdown]
# ------
# > 💭 **Reflection:**
# >
# > Do the probabilities that you estimated from the dataset make sense? Do they capture any patterns or rules of English that you know of?
# ------

# %% [markdown]
# As a final step in this part of the lab, look at the probability distribution for more contexts. Start with the context "The name."

# %%
context = "The name"
trigram_model[context]
# Out:
# {'means': 0.6666666666666666, "'Etosha'": 0.3333333333333333}

# %% [markdown]
# Now run the same code with a slightly altered context of "Their name."

# %%
context = "Their name"
trigram_model[context]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2357/152238866.py in <cell line: 0>()
#       1 context = "Their name"
# ----> 2 trigram_model[context]
#
# KeyError: 'Their name'

# %% [markdown]
# As you might observe, when you run the previous cell, this code results in an error. The reason for this is that the bigram "Their name" does not exist in the dataset. This means that it is not included in the trigram model that you built from the dataset and the dictionary that stores the probabilities does not contain an entry for this bigram, which is the cause of the `KeyError`.
#
# This highlights one limitation of the n-gram language model: for some contexts it cannot generate continuations. While there exist extensions to n-gram models that make them more robust, they are generally limited in their ability to generate continuations for arbitrary contexts.

# %% [markdown]
# ## Coding Activity 4: Using n-gram probabilities to sample next token
#
# The purpose of counting n-grams and using them to estimate conditional probability distributions, as you did in the previous activities, was to be able to sample from the distributions to generate new texts. In this activity, you will now explore how you can sample the next token using an n-gram language model.

# %% [markdown]
# As a first step, consider again the code from the previous lab that used the `random.choices` function to sample a token from a list of candidate tokens, repeated in the next cell.
#
# Recall that previously, you manually defined the possible next tokens and probabilities. During this activity, you will use the estimated probabilities from the n-gram model to define the possible next tokens and the associated probabilities.

# %% [markdown]
# Run the cell below multiple times to see different candidate words being picked:

# %%
# Define a list of tokens.
example_candidate_tokens = ["apple", "banana", "cherry"]

# Define corresponding probabilities for each fruit.
probabilities = [0.2, 0.5, 0.3]

# Sample one fruit based on the probabilities.
# The 'k=1' parameter instructs the function to return one item.
chosen_fruit = random.choices(
    example_candidate_tokens,
    weights=probabilities,
    k=1)[0]

print("Chosen fruit:", chosen_fruit)
# Out:
# Chosen fruit: apple

# %% [markdown]
# ------
# > 💻 **Your task:**
# >
# > Complete the following cell and use the probabilities in `trigram_model` to
# > 1. Generate a list of candidate tokens for the context "looking for."
# > 2. Extract the corresponding probabilities for each candidate token.
# >
# > Run the following cell multiple times to observe what tokens are being sampled.
# ------

# %%
context = "looking for"
candidate_tokens = []
candidate_tokens_probabilities = []

# Extract candidate tokens and associated probabilities from `trigram_model`.
# Add your code here.
for bigram, dict_bigram in trigram_model.items():
    if (context == bigram):
        for next_token, next_token_probability in dict_bigram.items():
            candidate_tokens.append(next_token)
            candidate_tokens_probabilities.append(next_token_probability)

print(f"Candidate tokens: {candidate_tokens}")
print(f"Candidate token probabilities: {candidate_tokens_probabilities}")

# Sample from the list of candidate tokens according to the
# associated probabilities.
next_token = random.choices(candidate_tokens,
                            weights=candidate_tokens_probabilities)[0]

print("\n\nSampled next token:")
print(context, next_token)
# Out:
# Candidate tokens: ['the', 'a', 'Banku', 'Tella,', 'Maafe,', 'Umqombothi,', 'sugarcane', 'crispy', 'warm', 'Doro', 'sambusa,', 'dodo,', 'Fura']
# Candidate token probabilities: [0.125, 0.53125, 0.03125, 0.03125, 0.03125, 0.03125, 0.03125, 0.03125, 0.03125, 0.03125, 0.03125, 0.03125, 0.03125]
#
#
# Sampled next token:
# looking for Banku

# %%
# @title Run this to test your code, or get a hint.
ngrams.test_candidate_tokens(
    trigram_model, candidate_tokens, candidate_tokens_probabilities
)
# Out:
# ✅ Nice! Your answer looks correct.

# %% [markdown]
# ## Generating texts
#
# You will now investigate the behavior of a function that can generate new texts for a given prompt using the probabilities of an n-gram model.
#
# Text generation using an n-gram model is an iterative process where each newly generated token is added to the existing context. This forms the basis for predicting the next token.
#
# Starting with an initial prompt text, the model uses the probability distribution derived from the n-gram counts to select the most likely next token. This again makes use of the `random.choices` function for picking the next token. Once this token has been generated, it is added to the context and the updated sequence is used to calculate the next probability distribution. This chain-like process continues until `num_tokens_to_generate` tokens have been generated.
#
# The following `generate_next_n_tokens` function implements this iterative generation process:

# %%
def generate_next_n_tokens(
    n: int,
    ngram_model: dict[str, dict[str, float]],
    prompt: str,
    num_tokens_to_generate: int,
) -> str:
    """Generates `num_tokens_to_generate` tokens following a given prompt using
    an n-gram language model.

    This function takes an n-gram model and uses it to predict the most
    likely next token for the given prompt. The generation process
    continues iteratively, appending predicted tokens to the prompt until the
    desired number of tokens is generated or a context is
    encountered for which the model has no predictions.

    Args:
        n: The size of the n-grams to use (e.g., 2 for a bigram model).
        ngram_model: A dictionary representing the n-gram language model.
        prompt: The starting text prompt for generating the next tokens.
        num_tokens_to_generate: The number of words to generate following
            the prompt.

    Returns:
        A string containing the original prompt followed by the generated
        tokens. If no valid continuation is found for a given context, the
        function will return the text generated up to that point and print a
        message indicating that no continuation could be found.
    """

    # Split prompt into individual tokens.
    generated_words = space_tokenize(prompt)

    for _ in range(num_tokens_to_generate):
        # Get last (n-1) tokens as context.
        context = generated_words[-(n - 1):]
        context = " ".join(context)
        if context in ngram_model:
            # Sample next word based on probabilities.
            next_word = random.choices(
                list(ngram_model[context].keys()),
                weights=ngram_model[context].values()
            )[0]

            generated_words.append(next_word)
        else:
            print(
                "⚠️ No valid continuation found. Change the prompt or"
                " try sampling another continuation.\n"
            )
            break

    return " ".join(generated_words)

# %% [markdown]
# ### Generating texts with a bigram model
#
# First, run the following cell multiple times to generate new continuations using a bigram model whose probabilities were estimated from the Africa Galore dataset.

# %%
prompt = "Jide was hungry so she went looking for"

# Construct a bigram model using the Africa Galore dataset.
bigram_model = build_ngram_model(dataset, n=2)

n = 2  # Bigram.
num_tokens_to_generate = 10  # Generate next n words.
generate_next_n_tokens(
    n=n,
    ngram_model=bigram_model,
    prompt=prompt,
    num_tokens_to_generate=num_tokens_to_generate,
)
# Out:
# 'Jide was hungry so she went looking for the highest summits, Batian and brewed from her passion for'

# %% [markdown]
# ### Generating texts with a trigram model
#
# Next, run the following cell multiple times to generate new continuations using the trigram model that you built in the previous activities.

# %%
prompt = "Jide was hungry so she went looking for"

n = 3  # Trigram.
num_tokens_to_generate = 10  # Generate next n words.
generate_next_n_tokens(
    n=n,
    ngram_model=trigram_model,
    prompt=prompt,
    num_tokens_to_generate=num_tokens_to_generate,
)
# Out:
# "Jide was hungry so she went looking for Doro Wat, served with a creamy liqueur from South Africa's"

# %% [markdown]
# The different results when running the cell multiple times are because the n-gram model is a stochastic model that samples the next token from a probability distribution. More probable next words have a high probability of getting picked but are not guaranteed to be picked.
#
# ------
# > 💭 **Reflection: Comparing the generations of bigram and trigram models**
# >
# > As you generate multiple continuations using both a bigram model and a trigram model, take note which continuations make more sense and tend to be grammatically correct. On average, does the bigram model or the trigram model produce more sensible continuations? Which model fails to produce a valid continuation more often?
# ------

# %% [markdown]
# ## What happens when you increase the $n$ in n-grams?
#
# While it intuitively seems that a larger context (greater $n$) would lead to better quality output by capturing more long-range dependencies in language,  it quickly runs into the problem of data sparsity since most n-grams will never be observed in the dataset.
#
# When moving from bigrams (pairs of tokens) to trigrams (triplets of tokens), the number of possible combinations increases exponentially, and many of these triplets rarely, if ever, appear in the dataset. This means that while bigram models can cover a significant portion of common token pairs, the majority of potential token sequences in trigram and higher-order models are underrepresented. This makes it more challenging for the model to reliably predict the next token.
#
# Consider a simple vocabulary of five tokens: "I", "love", "to", "eat", and "jollof". For bigrams, there are at most
# $$5 \times 5 = 25 $$
# possible combinations. In reality, however, your data might only include common pairs like "I love", "love to", "to eat", and "eat jollof". Now, when you move to trigrams (triplets of tokens), there are $$ 5 \times 5 \times 5 = 125$$ possible combinations. However, only a few of these, such as "I love to", "love to eat", and "to eat jollof", will actually appear in the data.
#
# Even with massive datasets, many of the higher-order n-grams will never appear in the corpus. This results in many zero counts for the probabilities. As the n-gram order increases, the number of potential combinations grows exponentially. This often leads to many combinations being rare or absent in the data, which makes reliable estimation of probabilities more difficult.

# %% [markdown]
# ## Summary
#
# This is the end of the **Experiment with N-Gram Models** lab.
#
# This lab provided a practical exploration of n-gram language models. Here are some key takeaways:
#
# **1. Functionality:**
#
# - You saw how n-gram models can be used to predict the next token in a sequence based on the preceding tokens (context).
# - N-gram models are relatively simple to implement by estimating conditional probabilities from n-gram counts in a dataset. These probabilities can then be used to repeatedly sample the next token and generate new continuations.
#
# **2. Data sparsity:**
#
# - Data sparsity is a major challenge for n-gram models, especially with higher-order n-grams (trigrams or larger).
# - This sparsity arises because many possible token combinations are rare or absent in real-world text data.
# - You observed this in the dataset. The dimensions of the trigram matrix are significantly larger than those of the bigram matrix, resulting in more zero values.
#
# **3. Randomness and text generation:**
#
# - While the model assigns probabilities to different next tokens, the actual choice is stochastic (random), resulting in different outputs for multiple runs.
# - While higher probabilities increase the chances of a token being picked, less frequent tokens can also be generated.
#
# **4. Considerations for text generation:**
#
# - The size of *n* can affect the quality of the generated text. Larger *n* might capture longer-range dependencies but can lead to data sparsity and repetitive outputs.
# - The model is unable to generate text following an n-gram that is not present in the dataset.
#
# In the next activity, you will reflect on some of the limitations of n-gram models and go on to compare them with more advanced models.

# %% [markdown]
# ## Solutions
#
# The following cells provide reference solutions to the coding activities above. If you really get stuck after trying to solve the activities yourself, you may want to consult these solutions.
#
# However, we recommend that you *only* look at the solutions after you have tried to solve the activities above *multiple times*. The best way to learn challenging concepts in computer science and artificial intelligence is to debug your code piece-by-piece until it works rather than copying existing solutions.
#
# If you feel stuck, you may want to first try to debug your code, for example, by adding additional print statements to see what your code is doing at every step. This will provide you with a much deeper understanding of the code and the materials. It will also provide you with practice on how to solve challenging coding problems beyond this course.
#
# To view the solutions for an activity, click on the arrow to the left of the activity name. If you consult the solutions, do not copy and paste them into the cells above. Instead, look at them and then type them manually into the cell. This will help you understand where you went wrong.

# %% [markdown]
# ### Coding Activity 1

# %%
# This is a complete implementation of `generate_ngrams`.
def generate_ngrams(text: str, n: int) -> list[tuple[str]]:
    """Generates n-grams from a given text.

    Args:
        text: The input text string.
        n: The size of the n-grams (e.g., 2 for bigrams, 3 for trigrams).

    Returns:
        A list of n-grams, each represented as a list of tokens.
    """

    # Tokenize text.
    tokens = space_tokenize(text)

    # Construct the list of n-grams.
    ngrams = []

    num_of_tokens = len(tokens)

    # The last n-gram will be tokens[num_of_tokens - n + 1: num_of_tokens + 1].
    for i in range(0, num_of_tokens - n + 1):
        ngrams.append(tuple(tokens[i:i+n]))

    return ngrams

# %% [markdown]
# ### Coding Activity 2

# %%
# This is a complete implementation of get_ngram_counts.
def get_ngram_counts(dataset: list[str], n: int) -> dict[str, Counter]:
    """Computes the n-gram counts from a dataset.

    This function takes a list of text strings (paragraphs or sentences) as
    input, constructs n-grams from each text, and creates a dictionary where:

    * Keys represent n-1 token long contexts `context`.
    * Values are a Counter object `counts` such that `counts[next_token]` is the
    * count of `next_token` following `context`.

    Args:
        dataset: The list of text strings in the dataset.
        n: The size of the n-grams to generate (e.g., 2 for bigrams, 3 for
            trigrams).

    Returns:
        A dictionary where keys are (n-1)-token contexts and values are Counter
        objects storing the counts of each next token for that context.

    """

    # Define the dictionary as a defaultdict that is automatically initialized
    # with an empty Counter object. This allows you to access and set the value
    # of ngram_counts[context][next_token] without initializing
    # ngram_counts[context] or ngram_counts[context][next_token] first.
    # See
    # https://docs.python.org/3/library/collections.html#collections.Counter and
    # https://docs.python.org/3/library/collections.html#collections.defaultdict
    # for more information on how to use defaultdict and Counter types.
    ngram_counts = defaultdict(Counter)

    # Loop through all paragraphs.
    for paragraph in dataset:
        # Loop through all n-grams for the paragraph.
        for ngram in generate_ngrams(paragraph, n):
            # Extract the context. This will be all but the last token.
            context = " ".join(ngram[:-1])
            # Extract the next token. This will be the last token of the n-gram.
            next_token = ngram[-1]
            # Increment the counter for the context - next_token pair by 1.
            ngram_counts[context][next_token] += 1

    return dict(ngram_counts)

# %% [markdown]
# ### Coding Activity 3

# %%
# Complete implemenation of build_ngram_model.
def build_ngram_model(dataset: list[str], n: int) -> dict[str, dict[str, float]]:
    """Builds an n-gram language model.

    This function takes a list of text strings (paragraphs or sentences) as
    input, generates n-grams from each text using the function get_ngram_counts
    and converts them into probabilities.  The resulting model is a dictionary,
    where keys are (n-1)-token contexts and values are dictionaries mapping
    possible next tokens to their conditional probabilities given the context.

    Args:
        dataset: A list of text strings representing the dataset.
        n: The size of the n-grams (e.g., 2 for a bigram model).

    Returns:
        A dictionary representing the n-gram language model, where keys are
        (n-1)-tokens contexts and values are dictionaries mapping possible next
        tokens to their conditional probabilities.
    """
    # A dictionary to store P(B | A).
    # ngram_model[context][token] should store P(token | context).
    ngram_model = {}

    # Use the ngram_counts as computed by the get_ngram_counts function.
    ngram_counts = get_ngram_counts(dataset, n)


    # Loop through the possible contexts. `context` is a string
    # and `next_tokens` is a dictionary mapping possible next tokens to their
    # counts of following `context`.
    for context, next_tokens in ngram_counts.items():

        # Compute Count(A) and P(B | A ) here.
        context_total_count = sum(next_tokens.values())
        ngram_model[context] = {}
        for token, count in next_tokens.items():
            ngram_model[context][token] = count / context_total_count

    return ngram_model

# %% [markdown]
# ### Coding Activity 4

# %%
# Include this code for extracting the candidate tokens and
# candidate tokens probabilities.

# Extract candidate tokens and associated probabilities from `trigram_model`.
for token, prob in trigram_model[context].items():
    candidate_tokens.append(token)
    candidate_tokens_probabilities.append(prob)

# %% [markdown]
# ## References
#
# [1] Ronen Eldan and Yuanzhi Li. 2023. Tiny Stories: How Small Can Language Models Be and Still Speak Coherent English. arXiv:2305.07759. Retrieved from [https://arxiv.org/pdf/2305.07759](https://arxiv.org/pdf/2305.07759).
